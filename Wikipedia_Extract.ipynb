# %% [markdown]
# # 8.2.1 Extract the Wikipedia movies JSON

# %%
import json
import pandas as pd
import numpy as np

#JSON library to extract the Wikipedia data
#Pandas library to create DataFrames
#NumPy library for converting data types

#On 8.3.8 we are instructed to import regular expressions as well:
import re

# %% [markdown]
# #### Note, the wikipedia data is messy so we don't want to convert it to a dataframe yet.  First we just want
# #### to load the json as it is.  This will allow us transform and clean it up like we want it before making it into a df.
# #### This is in contrast to the kaggle movie rating data that was already clean and so was immediately put into a df when imported.

# %%
with open('wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)

# %%
len(wiki_movies_raw)
# Out:
# 7311

# %%
# First 5 records
wiki_movies_raw[:5]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Directed by': 'Renny Harlin',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Story by': ['David Arnott', 'James Cappe'],
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Michael Tronick',
#   'Productioncompany ': 'Silver Pictures',
#   'Distributed by': '20th Century Fox',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$21.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/After_Dark,_My_Sweet',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098994/',
#   'title': 'After Dark, My Sweet',
#   'Directed by': 'James Foley',
#   'Produced by': ['Ric Kidney', 'Robert Redlin'],
#   'Screenplay by': ['James Foley', 'Robert Redlin'],
#   'Based on': ['the novel', 'After Dark, My Sweet', 'by', 'Jim Thompson'],
#   'Starring': ['Jason Patric',
#    'Rachel Ward',
#    'Bruce Dern',
#    'George Dickerson'],
#   'Music by': 'Maurice Jarre',
#   'Cinematography': 'Mark Plummer',
#   'Edited by': 'Howard E. Smith',
#   'Productioncompany ': 'Avenue Pictures',
#   'Distributed by': 'Avenue Pictures',
#   'Release date': ['May 17, 1990',
#    '(',
#    '1990-05-17',
#    ')',
#    '(Cannes Film Market)',
#    'August 24, 1990',
#    '(',
#    '1990-08-24',
#    ')',
#    '(United States)'],
#   'Running time': '114 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$6 million',
#   'Box office': '$2.7 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Air_America_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099005/',
#   'title': 'Air America',
#   'Directed by': 'Roger Spottiswoode',
#   'Produced by': 'Daniel Melnick',
#   'Screenplay by': ['John Eskow', 'Richard Rush'],
#   'Based on': ['Air America', 'by', 'Christopher Robbins'],
#   'Starring': ['Mel Gibson',
#    'Robert Downey Jr.',
#    'Nancy Travis',
#    'David Marshall Grant',
#    'Lane Smith'],
#   'Music by': 'Charles Gross',
#   'Cinematography': 'Roger Deakins',
#   'Edited by': ['John Bloom', 'Lois Freeman-Fox'],
#   'Productioncompany ': ['Carolco Pictures', 'IndieProd Company'],
#   'Distributed by': 'TriStar Pictures',
#   'Release date': ['August 10, 1990', '(', '1990-08-10', ')'],
#   'Running time': '113 minutes',
#   'Country': 'United States',
#   'Language': ['English', 'Lao'],
#   'Budget': '$35 million',
#   'Box office': '$57,718,089'},
#  {'url': 'https://en.wikipedia.org/wiki/Alice_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099012/',
#   'title': 'Alice',
#   'Directed by': 'Woody Allen',
#   'Produced by': 'Robert Greenhut',
#   'Written by': 'Woody Allen',
#   'Starring': ['Alec Baldwin',
#    'Blythe Danner',
#    'Judy Davis',
#    'Mia Farrow',
#    'William Hurt',
#    'Keye Luke',
#    'Joe Mantegna',
#    'Bernadette Peters'],
#   'Cinematography': 'Carlo Di Palma',
#   'Edited by': 'Susan E. Morse',
#   'Distributed by': 'Orion Pictures',
#   'Release date': ['December 25, 1990', '(', '1990-12-25', ')'],
#   'Running time': '106 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$12 million',
#   'Box office': '$7,331,647'},
#  {'url': 'https://en.wikipedia.org/wiki/Almost_an_Angel',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099018/',
#   'title': 'Almost an Angel',
#   'Directed by': 'John Cornell',
#   'Produced by': 'John Cornell',
#   'Written by': 'Paul Hogan',
#   'Starring': ['Paul Hogan', 'Elias Koteas', 'Linda Kozlowski'],
#   'Music by': 'Maurice Jarre',
#   'Cinematography': 'Russell Boyd',
#   'Edited by': 'David Stiven',
#   'Distributed by': 'Paramount Pictures',
#   'Release date': 'December 19, 1990',
#   'Running time': '95 minutes',
#   'Country': 'US',
#   'Language': 'English',
#   'Budget': '$25 million',
#   'Box office': '$6,939,946 (USA)'}]

# %%
# Last 5 records
wiki_movies_raw[-5:]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Holmes_%26_Watson',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt1255919/',
#   'title': 'Holmes & Watson',
#   'Directed by': 'Etan Cohen',
#   'Produced by': ['Will Ferrell',
#    'Adam McKay',
#    'Jimmy Miller',
#    'Clayton Townsend'],
#   'Screenplay by': 'Etan Cohen',
#   'Based on': ['Sherlock Holmes',
#    'and',
#    'Dr. Watson',
#    'by',
#    'Sir Arthur Conan Doyle'],
#   'Starring': ['Will Ferrell',
#    'John C. Reilly',
#    'Rebecca Hall',
#    'Rob Brydon',
#    'Steve Coogan',
#    'Ralph Fiennes'],
#   'Music by': 'Mark Mothersbaugh',
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Dean Zimmerman',
#   'Productioncompanies ': ['Columbia Pictures',
#    'Gary Sanchez Productions',
#    'Mosaic Media Group',
#    'Mimran Schur Pictures'],
#   'Distributed by': 'Sony Pictures Releasing',
#   'Release date': ['December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '90 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$42 million',
#   'Box office': '$41.9 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Vice_(2018_film)',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt6266538/',
#   'title': 'Vice',
#   'Directed by': 'Adam McKay',
#   'Produced by': ['Brad Pitt',
#    'Dede Gardner',
#    'Jeremy Kleiner',
#    'Kevin J. Messick',
#    'Will Ferrell',
#    'Adam McKay'],
#   'Written by': 'Adam McKay',
#   'Starring': ['Christian Bale',
#    'Amy Adams',
#    'Steve Carell',
#    'Sam Rockwell',
#    'Tyler Perry',
#    'Alison Pill',
#    'Lily Rabe',
#    'Jesse Plemons'],
#   'Music by': 'Nicholas Britell',
#   'Cinematography': 'Greig Fraser',
#   'Edited by': 'Hank Corwin',
#   'Productioncompany ': ['Plan B Entertainment',
#    'Gary Sanchez Productions',
#    'Annapurna Pictures'],
#   'Distributed by': 'Mirror Releasing',
#   'Release date': ['December 11, 2018',
#    '(',
#    '2018-12-11',
#    ')',
#    '(',
#    'Samuel Goldwyn Theater',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '132 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$60 million',
#   'Box office': '$76.1 million'},
#  {'url': 'https://en.wikipedia.org/wiki/On_the_Basis_of_Sex',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt4669788/',
#   'title': 'On the Basis of Sex',
#   'Directed by': 'Mimi Leder',
#   'Produced by': 'Robert W. Cort',
#   'Written by': 'Daniel Stiepleman',
#   'Starring': ['Felicity Jones',
#    'Armie Hammer',
#    'Justin Theroux',
#    'Sam Waterston',
#    'Kathy Bates'],
#   'Music by': 'Mychael Danna',
#   'Cinematography': 'Michael Grady',
#   'Edited by': 'Michelle Tesoro',
#   'Productioncompanies ': ['Focus Features',
#    '[1]',
#    'Participant Media',
#    '[1]',
#    'Robert Cort Productions',
#    '[1]',
#    'Alibaba Pictures',
#    '[2]'],
#   'Distributed by': 'Focus Features',
#   'Release date': ['November 8, 2018',
#    '(',
#    '2018-11-08',
#    ')',
#    '(',
#    'AFI Fest',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '120 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$38.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Destroyer_(2018_film)',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt7137380/',
#   'title': 'Destroyer',
#   'Directed by': 'Karyn Kusama',
#   'Produced by': ['Fred Berger', 'Phil Hay', 'Matt Manfredi'],
#   'Written by': ['Phil Hay', 'Matt Manfredi'],
#   'Starring': ['Nicole Kidman',
#    'Sebastian Stan',
#    'Toby Kebbell',
#    'Tatiana Maslany',
#    'Bradley Whitford',
#    'Jade Pettyjohn',
#    'Scoot McNairy'],
#   'Music by': 'Theodore Shapiro',
#   'Cinematography': 'Julie Kirkwood',
#   'Edited by': 'Plummy Tucker',
#   'Productioncompany ': ['30West',
#    'Automatik Entertainment',
#    'Annapurna Pictures'],
#   'Distributed by': 'Mirror Releasing',
#   'Release date': ['August 31, 2018',
#    '(',
#    '2018-08-31',
#    ')',
#    '(',
#    'Telluride',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '123 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$9 million',
#   'Box office': '$5.5 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Black_Mirror:_Bandersnatch',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt9495224/',
#   'title': 'Bandersnatch',
#   'Directed by': 'David Slade',
#   'Produced by': 'Russell McLean',
#   'Written by': 'Charlie Brooker',
#   'Starring': ['Fionn Whitehead',
#    'Will Poulter',
#    'Craig Parkinson',
#    'Alice Lowe',
#    'Asim Chaudhry'],
#   'Music by': 'Brian Reitzell',
#   'Cinematography': ['Aaron Morton', 'Jake Polonsky'],
#   'Edited by': 'Tony Kearns',
#   'Productioncompany ': ['House of Tomorrow', 'Netflix'],
#   'Distributed by': 'Netflix',
#   'Release date': ['28 December 2018', '(', '2018-12-28', ')'],
#   'Running time': 'Variable; 90 minutes for default path',
#   'Country': 'United Kingdom',
#   'Language': 'English'}]

# %%
# Some records in the middle
wiki_movies_raw[3600:3605]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
#   'Starring': ['Marc Rozendaal',
#    'Michael Silverman',
#    'David Warshofsky',
#    'Audra McDonald',
#    'Lois Smith'],
#   'Music by': ['Prince Paul', 'and', 'Don Newkirk'],
#   'Cinematography': 'Ben Kutchins',
#   'Edited by': 'Stephanie Sterner',
#   'Distributed by': 'Showtime Networks',
#   'Release date': ['January 16, 2004', '(', '2004-01-16', ')'],
#   'Running time': '93 minutes',
#   'Country': 'United States',
#   'Language': 'English'},
#  {'url': 'https://en.wikipedia.org/wiki/Beyond_the_Sea_(2004_film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0363473/',
#   'title': 'Beyond the Sea',
#   'Directed by': 'Kevin Spacey',
#   'Produced by': ['Kevin Spacey',
#    'Phillip Barry',
#    'Dana Brunetti',
#    'Arthur Friedman',
#    'Jan Fantl',
#    'Andy Paterson'],
#   'Written by': ['Lewis Colick', 'Kevin Spacey'],
#   'Starring': ['Kevin Spacey', 'Kate Bosworth', 'Bob Hoskins', 'John Goodman'],
#   'Music by': 'Bobby Darin',
#   'Cinematography': 'Eduardo Serra',
#   'Edited by': 'Trevor Waite',
#   'Productioncompany ': 'Trigger Street Productions',
#   'Distributed by': ['Lionsgate Films',
#    '(USA)',
#    'Entertainment Film Distributors',
#    '(UK)',
#    'GAGA',
#    '(Japan)',
#    'Maple Pictures',
#    '(Canada)'],
#   'Release date': ['December 17, 2004', '(', '2004-12-17', ')'],
#   'Running time': '118 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$25 million',
#   'Box office': '$8.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Big_Bounce_(2004_film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315824/',
#   'title': 'The Big Bounce',
#   'Directed by': 'George Armitage',
#   'Produced by': ['George Armitage', 'Steve Bing'],
#   'Screenplay by': 'Sebastian Gutierrez',
#   'Based on': ['The Big Bounce', 'by', 'Elmore Leonard'],
#   'Starring': ['Owen Wilson',
#    'Charlie Sheen',
#    'Morgan Freeman',
#    'Sara Foster',
#    'Gary Sinise'],
#   'Music by': 'George S. Clinton',
#   'Cinematography': 'Jeffrey L. Kimball',
#   'Edited by': 'Barry Malkin',
#   'Productioncompany ': 'Shangri-La Entertainment',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Release date': ['January 30, 2004', '(', '2004-01-30', ')'],
#   'Running time': '88 minutes',
#   'Language': 'English',
#   'Budget': '$50 million',
#   'Box office': '$6.8 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Birth_(film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0337876/',
#   'title': 'Birth',
#   'Directed by': 'Jonathan Glazer',
#   'Produced by': ['Lizie Gower', 'Nick Morris', 'Jean-Louis Piel'],
#   'Written by': ['Jean-Claude Carrière', 'Milo Addica', 'Jonathan Glazer'],
#   'Starring': ['Nicole Kidman',
#    'Cameron Bright',
#    'Danny Huston',
#    'Lauren Bacall'],
#   'Music by': 'Alexandre Desplat',
#   'Cinematography': 'Harris Savides',
#   'Edited by': ['Sam Sneade', 'Claus Wehlisch'],
#   'Distributed by': 'New Line Cinema',
#   'Release date': ['November 8, 2004', '(', '2004-11-08', ')'],
#   'Running time': '96 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$23.9 million'}]

# %% [markdown]
# # 8.3.3 Investigate the Wikipedia Data

# %%
wiki_movies_df = pd.DataFrame(wiki_movies_raw)
wiki_movies_df.head(10)
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
# 5        https://en.wikipedia.org/wiki/The_Ambulance  1990.0
# 6  https://en.wikipedia.org/wiki/American_Dream_(...  1990.0
# 7  https://en.wikipedia.org/wiki/American_Ninja_4...  1990.0
# 8     https://en.wikipedia.org/wiki/Andre%27s_Mother  1990.0
# 9    https://en.wikipedia.org/wiki/Angel_Town_(film)  1990.0
#
#                                imdb_link                               title  \
# 0  https://www.imdb.com/title/tt0098987/     The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/                After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                         Air America
# 3  https://www.imdb.com/title/tt0099012/                               Alice
# 4  https://www.imdb.com/title/tt0099018/                     Almost an Angel
# 5  https://www.imdb.com/title/tt0099026/                       The Ambulance
# 6  https://www.imdb.com/title/tt0099028/                      American Dream
# 7  https://www.imdb.com/title/tt0101326/  American Ninja 4: The Annihilation
# 8  https://www.imdb.com/title/tt0099037/                      Andre's Mother
# 9  https://www.imdb.com/title/tt0099039/                          Angel Town
#
#                                          Directed by  \
# 0                                       Renny Harlin
# 1                                        James Foley
# 2                                 Roger Spottiswoode
# 3                                        Woody Allen
# 4                                       John Cornell
# 5                                        Larry Cohen
# 6  [Barbara Kopple, Co-directors:, Cathy Caplan, ...
# 7                                   Cedric Sundstrom
# 8                                   Deborah Reinisch
# 9                                        Eric Karson
#
#                                      Produced by  \
# 0                     [Steve Perry, Joel Silver]
# 1                    [Ric Kidney, Robert Redlin]
# 2                                 Daniel Melnick
# 3                                Robert Greenhut
# 4                                   John Cornell
# 5  [Larry Cohen, Moctesuma Esparza, Robert Katz]
# 6                  [Arthur Cohn, Barbara Kopple]
# 7                             Ovidio G Assonitis
# 8                [Sarah Green, Deborah Reinisch]
# 9                     [Ash R. Shah, Eric Karson]
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
# 5                                         NaN                          NaN
# 6                                         NaN                          NaN
# 7                                         NaN                          NaN
# 8                                         NaN                          NaN
# 9                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                             Starring  ... Predecessor  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...         NaN
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...  ...         NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...         NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...         NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...         NaN
# 5  [Eric Roberts, James Earl Jones, Red Buttons, ...  ...         NaN
# 6                                                NaN  ...         NaN
# 7  [Michael Dudikoff, David Bradley, James Booth,...  ...         NaN
# 8     [Richard Thomas, Sada Thompson, Sylvia Sidney]  ...         NaN
# 9  [Olivier Gruner, Theresa Saldana, Frank Aragon...  ...         NaN
#
#   Founders Area served Products Services Russian Hebrew Revenue  \
# 0      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 1      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 2      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 3      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 4      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 5      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 6      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 7      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 8      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 9      NaN         NaN      NaN      NaN     NaN    NaN     NaN
#
#   Operating income Polish
# 0              NaN    NaN
# 1              NaN    NaN
# 2              NaN    NaN
# 3              NaN    NaN
# 4              NaN    NaN
# 5              NaN    NaN
# 6              NaN    NaN
# 7              NaN    NaN
# 8              NaN    NaN
# 9              NaN    NaN
#
# [10 rows x 193 columns]

# %%
wiki_movies_df.columns
# Out:
# Index(['url', 'year', 'imdb_link', 'title', 'Directed by', 'Produced by',
#        'Screenplay by', 'Story by', 'Based on', 'Starring',
#        ...
#        'Predecessor', 'Founders', 'Area served', 'Products', 'Services',
#        'Russian', 'Hebrew', 'Revenue', 'Operating income', 'Polish'],
#       dtype='object', length=193)

# %%
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
#  'Cover artist',
#  'Series',
#  'Set in',
#  'Adaptation by',
#  'Suggested by',
#  'Biographical data',
#  'Born',
#  'Died',
#  'Resting place',
#  'Occupation',
#  'Years active',
#  'Spouse(s)',
#  'Children',
#  'Parent(s)',
#  'Genres',
#  'Instruments',
#  'Labels',
#  'Website',
#  'Traditional',
#  'Mandarin',
#  'Type',
#  'Industry',
#  'Fate',
#  'Founded',
#  'Founder',
#  'Headquarters',
#  'Parent',
#  'Released',
#  'Recorded',
#  'Venue',
#  'Length',
#  'Label',
#  'Director',
#  'Producer',
#  'Area',
#  'Coordinates',
#  'Status',
#  'Opening date',
#  'Closing date',
#  'Replaced',
#  'Replaced by',
#  'Name',
#  'Attraction type',
#  'Music',
#  'Duration',
#  'Simplified Chinese',
#  'Traditional Chinese',
#  'Hanyu Pinyin',
#  'Literal meaning',
#  'Transcriptions',
#  'Bopomofo',
#  'Gwoyeu Romatzyh',
#  'Wade–Giles',
#  'IPA',
#  'Yale Romanization',
#  'Jyutping',
#  'Hokkien POJ',
#  'Animation by',
#  'Color process',
#  'Engine(s)',
#  'Genre(s)',
#  'Actor control',
#  'Production company',
#  'Release(s)',
#  'Format(s)',
#  'Simplified',
#  'Characters',
#  'Date premiered',
#  'Place premiered',
#  'Setting',
#  'Original language',
#  'Subject',
#  'Published',
#  'Dewey Decimal',
#  'Text',
#  'Illustrator',
#  'Original title',
#  'Published in English',
#  'French',
#  'Developed by',
#  'Ending theme',
#  'No. of seasons',
#  'Nationality',
#  'Portrayed by',
#  'Alias',
#  'Species',
#  'Gender',
#  'Family',
#  'Alma mater',
#  'Camera setup',
#  'Novel(s)',
#  'Comics',
#  'Film(s)',
#  'Screen story by',
#  'Hangul',
#  'Revised Romanization',
#  'McCune–Reischauer',
#  'Developer(s)',
#  'Publisher(s)',
#  'Designer(s)',
#  'Programmer(s)',
#  'Artist(s)',
#  'Writer(s)',
#  'Engine',
#  'Platform(s)',
#  'Release',
#  'Mode(s)',
#  'Original work',
#  'Television series',
#  'Japanese',
#  'Hepburn',
#  'Literally',
#  'Cantonese',
#  'Full name',
#  'Height',
#  'Seasons',
#  'Chinese',
#  'Other names',
#  'Relatives',
#  'Yiddish',
#  'Formerly',
#  'Key people',
#  'Total assets',
#  'Owner',
#  'Number of employees',
#  'Divisions',
#  'Subsidiaries',
#  'Arabic',
#  'Romanized',
#  'Predecessor',
#  'Founders',
#  'Area served',
#  'Products',
#  'Services',
#  'Russian',
#  'Hebrew',
#  'Revenue',
#  'Operating income',
#  'Polish']

# %%
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie]
len(wiki_movies)
# Out:
# 7080

# %%
wiki_movies_df = pd.DataFrame(wiki_movies)
wiki_movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7075    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7076     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7077  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7078  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7079  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1     https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2     https://www.imdb.com/title/tt0099005/                      Air America
# 3     https://www.imdb.com/title/tt0099012/                            Alice
# 4     https://www.imdb.com/title/tt0099018/                  Almost an Angel
# ...                                     ...                              ...
# 7075  https://www.imdb.com/title/tt1255919/                  Holmes & Watson
# 7076  https://www.imdb.com/title/tt6266538/                             Vice
# 7077  https://www.imdb.com/title/tt4669788/              On the Basis of Sex
# 7078  https://www.imdb.com/title/tt7137380/                        Destroyer
# 7079  https://www.imdb.com/title/tt9495224/                     Bandersnatch
#
#              Directed by                                        Produced by  \
# 0           Renny Harlin                         [Steve Perry, Joel Silver]
# 1            James Foley                        [Ric Kidney, Robert Redlin]
# 2     Roger Spottiswoode                                     Daniel Melnick
# 3            Woody Allen                                    Robert Greenhut
# 4           John Cornell                                       John Cornell
# ...                  ...                                                ...
# 7075          Etan Cohen  [Will Ferrell, Adam McKay, Jimmy Miller, Clayt...
# 7076          Adam McKay  [Brad Pitt, Dede Gardner, Jeremy Kleiner, Kevi...
# 7077          Mimi Leder                                     Robert W. Cort
# 7078        Karyn Kusama             [Fred Berger, Phil Hay, Matt Manfredi]
# 7079         David Slade                                     Russell McLean
#
#                                    Screenplay by                     Story by  \
# 0     [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                   [James Foley, Robert Redlin]                          NaN
# 2                     [John Eskow, Richard Rush]                          NaN
# 3                                            NaN                          NaN
# 4                                            NaN                          NaN
# ...                                          ...                          ...
# 7075                                  Etan Cohen                          NaN
# 7076                                         NaN                          NaN
# 7077                                         NaN                          NaN
# 7078                                         NaN                          NaN
# 7079                                         NaN                          NaN
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7075  [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
# 7076                                                NaN
# 7077                                                NaN
# 7078                                                NaN
# 7079                                                NaN
#
#                                                Starring  ... Hepburn  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...     NaN
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...  ...     NaN
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...     NaN
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...     NaN
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...     NaN
# ...                                                 ...  ...     ...
# 7075  [Will Ferrell, John C. Reilly, Rebecca Hall, R...  ...     NaN
# 7076  [Christian Bale, Amy Adams, Steve Carell, Sam ...  ...     NaN
# 7077  [Felicity Jones, Armie Hammer, Justin Theroux,...  ...     NaN
# 7078  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...  ...     NaN
# 7079  [Fionn Whitehead, Will Poulter, Craig Parkinso...  ...     NaN
#
#      Literally Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew  \
# 0          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 1          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 2          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 3          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 4          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# ...        ...       ...     ...     ...    ...       ...     ...    ...
# 7075       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7076       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7077       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7078       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7079       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
#
#      Polish
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 7075    NaN
# 7076    NaN
# 7077    NaN
# 7078    NaN
# 7079    NaN
#
# [7080 rows x 78 columns]

# %%
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie
                   and 'No. of episodes' not in movie]

# %%
wiki_movies_df = pd.DataFrame(wiki_movies)
wiki_movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7071    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7072     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7073  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7074  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7075  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1     https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2     https://www.imdb.com/title/tt0099005/                      Air America
# 3     https://www.imdb.com/title/tt0099012/                            Alice
# 4     https://www.imdb.com/title/tt0099018/                  Almost an Angel
# ...                                     ...                              ...
# 7071  https://www.imdb.com/title/tt1255919/                  Holmes & Watson
# 7072  https://www.imdb.com/title/tt6266538/                             Vice
# 7073  https://www.imdb.com/title/tt4669788/              On the Basis of Sex
# 7074  https://www.imdb.com/title/tt7137380/                        Destroyer
# 7075  https://www.imdb.com/title/tt9495224/                     Bandersnatch
#
#              Directed by                                        Produced by  \
# 0           Renny Harlin                         [Steve Perry, Joel Silver]
# 1            James Foley                        [Ric Kidney, Robert Redlin]
# 2     Roger Spottiswoode                                     Daniel Melnick
# 3            Woody Allen                                    Robert Greenhut
# 4           John Cornell                                       John Cornell
# ...                  ...                                                ...
# 7071          Etan Cohen  [Will Ferrell, Adam McKay, Jimmy Miller, Clayt...
# 7072          Adam McKay  [Brad Pitt, Dede Gardner, Jeremy Kleiner, Kevi...
# 7073          Mimi Leder                                     Robert W. Cort
# 7074        Karyn Kusama             [Fred Berger, Phil Hay, Matt Manfredi]
# 7075         David Slade                                     Russell McLean
#
#                                    Screenplay by                     Story by  \
# 0     [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                   [James Foley, Robert Redlin]                          NaN
# 2                     [John Eskow, Richard Rush]                          NaN
# 3                                            NaN                          NaN
# 4                                            NaN                          NaN
# ...                                          ...                          ...
# 7071                                  Etan Cohen                          NaN
# 7072                                         NaN                          NaN
# 7073                                         NaN                          NaN
# 7074                                         NaN                          NaN
# 7075                                         NaN                          NaN
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
# 7072                                                NaN
# 7073                                                NaN
# 7074                                                NaN
# 7075                                                NaN
#
#                                                Starring  ... Hepburn  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...     NaN
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...  ...     NaN
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...     NaN
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...     NaN
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...     NaN
# ...                                                 ...  ...     ...
# 7071  [Will Ferrell, John C. Reilly, Rebecca Hall, R...  ...     NaN
# 7072  [Christian Bale, Amy Adams, Steve Carell, Sam ...  ...     NaN
# 7073  [Felicity Jones, Armie Hammer, Justin Theroux,...  ...     NaN
# 7074  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...  ...     NaN
# 7075  [Fionn Whitehead, Will Poulter, Craig Parkinso...  ...     NaN
#
#      Literally Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew  \
# 0          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 1          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 2          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 3          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 4          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# ...        ...       ...     ...     ...    ...       ...     ...    ...
# 7071       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7072       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7073       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7074       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7075       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
#
#      Polish
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 7071    NaN
# 7072    NaN
# 7073    NaN
# 7074    NaN
# 7075    NaN
#
# [7076 rows x 75 columns]

# %% [markdown]
# # 8.3.5 Create a Function to Clean the Data Part 1

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]
#wiki_movies_df[wiki_movies_df['Polish'].notnull()]
# Out:
#                                                   url  year  \
# 6834  https://en.wikipedia.org/wiki/The_Insult_(film)  2018
# 7058   https://en.wikipedia.org/wiki/Capernaum_(film)  2018
#
#                                   imdb_link       title    Directed by  \
# 6834  https://www.imdb.com/title/tt7048622/  The Insult   Ziad Doueiri
# 7058  https://www.imdb.com/title/tt8267604/   Capernaum  Nadine Labaki
#
#                                             Produced by  \
# 6834  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, A...
# 7058                    [Michel Merkt, Khaled Mouzanar]
#
#                                           Screenplay by  \
# 6834                                                NaN
# 7058  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
#
#                                                Story by Based on  \
# 6834                                                NaN      NaN
# 7058  [Georges Khabbaz, Nadine Labaki, Michelle Kese...      NaN
#
#                                                Starring  ... Hepburn  \
# 6834                       [Adel Karam, Kamel El Basha]  ...     NaN
# 7058  [Zain Al Rafeea, Yordanos Shiferaw, Boluwatife...  ...     NaN
#
#         Literally Cantonese Chinese Yiddish       Arabic        Romanized  \
# 6834  Case No. 23       NaN     NaN     NaN  قضية رقم ٢٣  Qadiyya raqm 23
# 7058          NaN       NaN     NaN     NaN    کفرناحوم‎              NaN
#
#      Russian Hebrew Polish
# 6834     NaN    NaN    NaN
# 7058     NaN    NaN    NaN
#
# [2 rows x 75 columns]

# %%
#wiki_movies_df['Arabic'].value_counts()

# %%
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Also known as',
#  'Animation by',
#  'Arabic',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cantonese',
#  'Chinese',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'French',
#  'Genre',
#  'Hangul',
#  'Hebrew',
#  'Hepburn',
#  'Japanese',
#  'Label',
#  'Language',
#  'Length',
#  'Literally',
#  'Mandarin',
#  'McCune–Reischauer',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Original title',
#  'Picture format',
#  'Polish',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Revised Romanization',
#  'Romanized',
#  'Running time',
#  'Russian',
#  'Screen story by',
#  'Screenplay by',
#  'Simplified',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Traditional',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'Yiddish',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
pd.set_option('display.max_colwidth',1)

#GO THROUGH ALL the columns you think may represent alternate titles for diff languages

#Arabic, Cantonese, Chinese, French, Hangul, Hebrew, Hepburn, 
#Japanese, Literally,  Mandarin, McCune–Reischauer, Original title, 
#Polish,  Revised Romanization, Romanized, Russian, Simplified, Traditional, Yiddish

#wiki_movies_df[wiki_movies_df['Arabic'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Cantonese'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Chinese'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['French'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Hangul'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Hebrew'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Hepburn'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Japanese'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Literally'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Mandarin'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['McCune-Reischauer'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Original Title'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Polish'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Revised Romantization'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Romanized'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Russian'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Simplified'].notnull()]['url']
#wiki_movies_df[wiki_movies_df['Traditional'].notnull()]['url']
wiki_movies_df[wiki_movies_df['Yiddish'].notnull()]['url']
# Out:
# 6719    https://en.wikipedia.org/wiki/Menashe_(film)
# Name: url, dtype: object

# %%
# ALEX, this is just a personal test (not in the module lesson)
# to actually see how "Arabic" would look in the JSON if you wanted.

#for i in range (len(wiki_movies_raw)):
#    if "Arabic" in list(wiki_movies_raw[i].keys()):
#       print(i)
#       print(wiki_movies_raw[i])

# %% [markdown]
# #### Step 1: Make an empty dict to hold all of the alternative titles

# %% [markdown]
# #### Step 2: Loop through a list of all alternative title keys.

# %% [markdown]
# #### Step 2a: Check if the current key exists in the movie object.

# %% [markdown]
# #### Step 2b: If so, remove the key-value pair and add to the alternative titles dictionary.

# %% [markdown]
# #### Step 3: After looping through every key, add the alternative titles dict to the movie object.

# %%
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles

    return movie

# %%
clean_movies = [clean_movie(movie) for movie in wiki_movies]

# %%
wiki_movies_df = pd.DataFrame(clean_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Length',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Picture format',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Running time',
#  'Screen story by',
#  'Screenplay by',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
pd.set_option('display.max_columns', None)

wiki_movies_df[wiki_movies_df['alt_titles'].notnull()]
# Out:
#                                                               url  year  \
# 858   https://en.wikipedia.org/wiki/The_Wedding_Banquet            1993
# 1342  https://en.wikipedia.org/wiki/Night_Watch_(1995_film)        1995
# 1534  https://en.wikipedia.org/wiki/East_Palace,_West_Palace       1996
# 1888  https://en.wikipedia.org/wiki/The_Fifth_Element              1997
# 3413  https://en.wikipedia.org/wiki/Wonderful_Days_(film)          2003
# 4238  https://en.wikipedia.org/wiki/Shark_Bait                     2006
# 4790  https://en.wikipedia.org/wiki/Waltz_with_Bashir              2008
# 6393  https://en.wikipedia.org/wiki/When_Marnie_Was_There          2015
# 6456  https://en.wikipedia.org/wiki/Ip_Man_3                       2016
# 6613  https://en.wikipedia.org/wiki/The_Great_Wall_(film)          2017
# 6620  https://en.wikipedia.org/wiki/Rock_Dog                       2017
# 6661  https://en.wikipedia.org/wiki/Born_in_China                  2017
# 6719  https://en.wikipedia.org/wiki/Menashe_(film)                 2017
# 6829  https://en.wikipedia.org/wiki/Mary_and_the_Witch%27s_Flower  2018
# 6834  https://en.wikipedia.org/wiki/The_Insult_(film)              2018
# 6849  https://en.wikipedia.org/wiki/Loveless_(film)                2018
# 6862  https://en.wikipedia.org/wiki/Foxtrot_(2017_film)            2018
# 7009  https://en.wikipedia.org/wiki/My_Hero_Academia:_Two_Heroes   2018
# 7054  https://en.wikipedia.org/wiki/Shoplifters                    2018
# 7058  https://en.wikipedia.org/wiki/Capernaum_(film)               2018
# 7070  https://en.wikipedia.org/wiki/Cold_War_(2018_film)           2018
#
#                                   imdb_link  \
# 858   https://www.imdb.com/title/tt0107156/
# 1342  https://www.imdb.com/title/tt0113984/
# 1534  https://www.imdb.com/title/tt0119007/
# 1888  https://www.imdb.com/title/tt0119116/
# 3413  https://www.imdb.com/title/tt0353014/
# 4238  https://www.imdb.com/title/tt0820142/
# 4790  https://www.imdb.com/title/tt1185616/
# 6393  https://www.imdb.com/title/tt3398268/
# 6456  https://www.imdb.com/title/tt2888046/
# 6613  https://www.imdb.com/title/tt2034800/
# 6620  https://www.imdb.com/title/tt2822672/
# 6661  https://www.imdb.com/title/tt4629266/
# 6719  https://www.imdb.com/title/tt6333086/
# 6829  https://www.imdb.com/title/tt6336356/
# 6834  https://www.imdb.com/title/tt7048622/
# 6849  https://www.imdb.com/title/tt6304162/
# 6862  https://www.imdb.com/title/tt6896536/
# 7009  https://www.imdb.com/title/tt7745068/
# 7054  https://www.imdb.com/title/tt8075192/
# 7058  https://www.imdb.com/title/tt8267604/
# 7070  https://www.imdb.com/title/tt6543652/
#
#                                        title                      Directed by  \
# 858   The Wedding Banquet                     Ang Lee
# 1342  Nightwatch                              David Jackson
# 1534  East Palace, West Palace                Zhang Yuan
# 1888  The Fifth Element                       Luc Besson
# 3413  Wonderful Days                          Kim Moon-saeng
# 4238  Shark Bait (AKA: The Reef: Shark Bait)  [Howard E. Baker, John Fox]
# 4790  Waltz with Bashir                       Ari Folman
# 6393  When Marnie Was There                   Hiromasa Yonebayashi
# 6456  Ip Man 3                                Wilson Yip
# 6613  The Great Wall                          Zhang Yimou
# 6620  Rock Dog                                Ash Brannon
# 6661  Born in China                           Lu Chuan
# 6719  Menashe                                 [Joshua Z. Weinstein, [, yi, ]]
# 6829  Mary and The Witch's Flower             Hiromasa Yonebayashi
# 6834  The Insult                              Ziad Doueiri
# 6849  Loveless                                Andrey Zvyagintsev
# 6862  Foxtrot                                 Samuel Maoz
# 7009  My Hero Academia: Two Heroes            Kenji Nagasaki
# 7054  Shoplifters                             Hirokazu Kore-eda
# 7058  Capernaum                               Nadine Labaki
# 7070  Cold War                                Paweł Pawlikowski
#
#                                                                               Produced by  \
# 858   [Ang Lee, Ted Hope, James Schamus]
# 1342  NaN
# 1534  [Christophe Jung, Christophe Ménager, Zhang Yuan, Willy Tsao]
# 1888  Patrice Ledoux
# 3413  [Hwang K. S., Kyeong Hag Lee]
# 4238  NaN
# 4790  [Ari Folman, Serge Lalou, Gerhard Meixner, Yael Nahlieli, Roman Paul]
# 6393  Yoshiaki Nishimura
# 6456  Raymond Wong
# 6613  [Thomas Tull, Charles Roven, Jon Jashni, Peter Loehr, [1]]
# 6620  [Amber Wang, David B. Miller, Rob Feng, Joyce Lou, Zheng Jun]
# 6661  [Roy Conli, Brian Leith, Phil Chapman]
# 6719  [Alex Lipschultz, Traci Carlson, Joshua Z. Weinstein, Daniel Finkelman, Yoni Brook]
# 6829  Yoshiaki Nishimura
# 6834  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, Antoun Sehnaoui, Nadia Turincev]
# 6849  [Alexander Rodnyansky, Sergey Melkumov, Gleb Fetisov]
# 6862  [Eitan Mansuri, [, he, ]]
# 7009  [Yoshihiro Oyabu, Koji Nagai, Wakana Okamura, Kazumasa Sanjōba]
# 7054  [Matsuzaki Kaoru, Yose Akihiko, Taguchi Hijiri]
# 7058  [Michel Merkt, Khaled Mouzanar]
# 7070  [Tanya Seghatchian, Ewa Puszczyńska]
#
#                                             Screenplay by  \
# 858   NaN
# 1342  NaN
# 1534  NaN
# 1888  [Luc Besson, Robert Mark Kamen]
# 3413  NaN
# 4238  NaN
# 4790  NaN
# 6393  [Masashi Andō, Keiko Niwa, Hiromasa Yonebayashi]
# 6456  NaN
# 6613  [Carlo Bernard, Doug Miro, Tony Gilroy]
# 6620  [Ash Brannon, Kurt Voelker]
# 6661  [David Fowler, Brian Leith, Phil Chapman, Lu Chuan]
# 6719  NaN
# 6829  [Riko Sakaguchi, Hiromasa Yonebayashi]
# 6834  NaN
# 6849  [Oleg Negin, Andrey Zvyagintsev]
# 6862  NaN
# 7009  NaN
# 7054  NaN
# 7058  [Nadine Labaki, Jihad Hojaily, Michelle Keserwany]
# 7070  NaN
#
#                                                                                   Story by  \
# 858   NaN
# 1342  NaN
# 1534  NaN
# 1888  Luc Besson
# 3413  NaN
# 4238  NaN
# 4790  NaN
# 6393  NaN
# 6456  NaN
# 6613  [Max Brooks, Edward Zwick, Marshall Herskovitz]
# 6620  [Ash Brannon, Zheng Jun]
# 6661  NaN
# 6719  NaN
# 6829  NaN
# 6834  NaN
# 6849  NaN
# 6862  NaN
# 7009  NaN
# 7054  NaN
# 7058  [Georges Khabbaz, Nadine Labaki, Michelle Keserwany, Jihad Hojaily, Khaled Mouzanar]
# 7070  NaN
#
#                                             Based on  \
# 858   NaN
# 1342  NaN
# 1534  NaN
# 1888  NaN
# 3413  NaN
# 4238  NaN
# 4790  NaN
# 6393  [When Marnie Was There, by, Joan G. Robinson]
# 6456  NaN
# 6613  NaN
# 6620  [Tibetan Rock Dog, by Zheng Jun]
# 6661  NaN
# 6719  NaN
# 6829  [The Little Broomstick, by, Mary Stewart, [1]]
# 6834  NaN
# 6849  NaN
# 6862  NaN
# 7009  [My Hero Academia, by, Kōhei Horikoshi]
# 7054  NaN
# 7058  NaN
# 7070  NaN
#
#                                                                                                                                                                                          Starring  \
# 858   [Ah-Leh Gua, Sihung Lung, May Chin, Winston Chao, Mitchell Lichtenstein]
# 1342  [Pierce Brosnan, ,, Alexandra Paul]
# 1534  [Si Han, Hu Jun, Zhao Wei]
# 1888  [Bruce Willis, Gary Oldman, Ian Holm, Chris Tucker, Milla Jovovich]
# 3413  [Korean, Ji Hoon Choi, Yeong Seon Eun, In Seong O, Kim Jong-kook, English, Marc Worden, Cathy Cavadini, Kirk Thornton, David Naughton]
# 4238  [Freddie Prinze, Jr., Evan Rachel Wood, Donal Logue, Andy Dick, Fran Drescher, John Rhys-Davies, Rob Schneider]
# 4790  Ari Folman
# 6393  [Sara Takatsuki, Kasumi Arimura]
# 6456  [Donnie Yen, Zhang Jin, Lynn Hung, Patrick Tam, Karena Ng, Kent Cheng, Bryan Leung, Louis Cheung, Danny Chan, Mike Tyson, Tats Lau]
# 6613  [Matt Damon, Jing Tian, Pedro Pascal, Willem Dafoe, Andy Lau]
# 6620  [Luke Wilson, Eddie Izzard, J. K. Simmons, Lewis Black, Kenan Thompson, Mae Whitman, Jorge Garcia, Matt Dillon, Sam Elliott]
# 6661  NaN
# 6719  [Menashe Lustig, [, yi, ], Ruben Niborski, Yoel Weisshaus, Meyer Schwartz]
# 6829  [Hana Sugisaki, Yūki Amami, Fumiyo Kohinata]
# 6834  [Adel Karam, Kamel El Basha]
# 6849  [Maryana Spivak, Aleksey Rozin, Matvey Novikov, Marina Vasilyeva, Andris Keišs]
# 6862  [Lior Ashkenazi, Sarah Adler]
# 7009  NaN
# 7054  [Lily Franky, Sakura Ando, Mayu Matsuoka, Kairi Jō, Miyu Sasaki, Kirin Kiki]
# 7058  [Zain Al Rafeea, Yordanos Shiferaw, Boluwatife Bankole, Kawthar Al Haddad, Fadi Kamel Youssef, Nour el Husseini, Alaa Chouchnieh, Cedra Izam, Nadine Labaki, Joseph Jimbazian, Farah Hasno]
# 7070  [Joanna Kulig, Tomasz Kot, Borys Szyc, Agata Kulesza, Cédric Kahn, Jeanne Balibar]
#
#                                                             Narrated by  \
# 858   NaN
# 1342  NaN
# 1534  NaN
# 1888  NaN
# 3413  NaN
# 4238  NaN
# 4790  NaN
# 6393  NaN
# 6456  NaN
# 6613  NaN
# 6620  NaN
# 6661  [John Krasinski, (American release), Zhou Xun, (Chinese release)]
# 6719  NaN
# 6829  NaN
# 6834  NaN
# 6849  NaN
# 6862  NaN
# 7009  NaN
# 7054  NaN
# 7058  NaN
# 7070  NaN
#
#                                   Music by                     Cinematography  \
# 858   Mader                                 Jong Lin
# 1342  NaN                                   Michael Negrin
# 1534  Xiang Min                             Zhang Jian
# 1888  Éric Serra                            Thierry Arbogast
# 3413  Won II                                NaN
# 4238  Christopher Lennertz                  NaN
# 4790  Max Richter                           NaN
# 6393  Takatsugu Muramatsu                   Atsushi Okuo
# 6456  Kenji Kawai                           Kenny Tse
# 6613  Ramin Djawadi                         [Stuart Dryburgh, Zhao Xiaoding]
# 6620  Rolfe Kent                            NaN
# 6661  Barnaby Taylor                        NaN
# 6719  [Aaron Martin, Dag Rosenqvist]        [Yoni Brook, Joshua Z. Weinstein]
# 6829  Takatsugu Muramatsu                   Toru Fukushi
# 6834  Éric Neveux                           Tommaso Fiorilli
# 6849  [Evgueni Galperine, Sacha Galperine]  Mikhail Krichman
# 6862  [Ophir Leibovitch, Amit Poznanky]     Giora Bejach
# 7009  Yuki Hayashi                          NaN
# 7054  Haruomi Hosono                        Kondo Ryuto
# 7058  Khaled Mouzanar                       Christopher Aoun
# 7070  NaN                                   Łukasz Żal
#
#                                          Edited by  \
# 858   Tim Squyres
# 1342  NaN
# 1534  Vincent Lévy
# 1888  Sylvie Landra
# 3413  NaN
# 4238  Tom Sanders
# 4790  Nili Feller
# 6393  Rie Matsubara
# 6456  Cheung Ka-fai
# 6613  [Mary Jo Markey, Craig Wood]
# 6620  [Ivan Bilancio, Ed Fuller]
# 6661  Matthew Meech
# 6719  Scott Cummings
# 6829  NaN
# 6834  Dominique Marcombe
# 6849  Anna Mass
# 6862  [Arik Lahav Leibovich, [, he, ], Guy Nemesh]
# 7009  NaN
# 7054  Hirokazu Kore-eda
# 7058  Konstantin Bock
# 7070  Jaroslaw Kaminski
#
#                                                                                                              Productioncompany   \
# 858   Good Machine
# 1342  NaN
# 1534  NaN
# 1888  [Columbia Pictures, Gaumont]
# 3413  [Endgame Productions Inc., Masquerade Films, Maxmedia, Tin House Productions]
# 4238  NaN
# 4790  NaN
# 6393  Studio Ghibli
# 6456  NaN
# 6613  [Legendary East, Atlas Entertainment, [1], China Film Group, Le Vision Pictures]
# 6620  NaN
# 6661  [Disneynature, Shanghai Media Group, Chuan Films, Brian Leith Productions, [1]]
# 6719  NaN
# 6829  [Studio Ponoc, Nippon Television Network]
# 6834  [Ezekiel Films, Tessalit Productions, Rouge International]
# 6849  [Arte France Cinéma, Why Not Productions]
# 6862  Bord Cadre Films
# 7009  Bones
# 7054  Aoi Pro, Inc.
# 7058  Mooz Films
# 7070  [Opus Film, Polish Film Institute, MK2 Films, Film4, BFI, Protagonist Pictures, Apocalypso Pictures, MK Productions, [a]]
#
#                                                                                          Distributed by  \
# 858   The Samuel Goldwyn Company
# 1342  NaN
# 1534  Fortissimo Films
# 1888  [Gaumont Buena Vista International, [1], (France), Sony Pictures Releasing, [2], (United States)]
# 3413  [Palisades Tartan, (English releases), Gainax, (Japan), Pathé, (France)]
# 4238  CJ Entertainment
# 4790  Sony Pictures Classics
# 6393  Toho
# 6456  Pegasus Motion Pictures
# 6613  [Universal Pictures, (US/international), [2], China Film Group, (China), [3]]
# 6620  [Huayi Brothers, (China), Summit Premiere, (United States)]
# 6661  [Walt Disney Studios, Motion Pictures, Shanghai Media Group, (China), [2]]
# 6719  A24
# 6829  Toho
# 6834  [Diaphana Films, (France), Italia Film, (Lebanon]
# 6849  [Sony Pictures Releasing, (Russia), [1]]
# 6862  NaN
# 7009  Toho
# 7054  GAGA Pictures
# 7058  Sony Pictures Classics
# 7070  [Kino Świat (Poland), Diaphana Films (France), Curzon Artificial Eye, (United Kingdom)]
#
#                                                                                                                                                                                  Release date  \
# 858   [4 August 1993, (, 1993-08-04, ), (United States)]
# 1342  NaN
# 1534  [November 1996, (, 1996-11, ), (, Mar del Plata, )]
# 1888  [7 May 1997, (, 1997-05-07, )]
# 3413  [July 17, 2003, (, 2003-07-17, )]
# 4238  [July 7, 2006, (, 2006-07-07, ), (South Korea)]
# 4790  [13 May 2008, (, 2008-05-13, ), (, Cannes, ), 5 June 2008, (, 2008-06-05, ), (Israel)]
# 6393  [19 July 2014, (, 2014-07-19, )]
# 6456  [16 December 2015, (, 2015-12-16, ), (Hong Kong premiere), 24 December 2015, (, 2015-12-24, ), (Hong Kong)]
# 6613  [December 6, 2016, (, 2016-12-06, ), (, Beijing, ), December 16, 2016, (, 2016-12-16, ), (China), February 17, 2017, (, 2017-02-17, ), (United States)]
# 6620  [June 2016, (, 2016-06, ), (, SIFF, ), [2], July 8, 2016, (, 2016-07-08, ), (China), [3], [4], February 24, 2017, (, 2017-02-24, ), (United States)]
# 6661  [August 12, 2016, (, 2016-08-12, ), (China), April 21, 2017, (, 2017-04-21, ), (United States)]
# 6719  [January 23, 2017, (, 2017-01-23, ), (, Sundance, ), July 28, 2017, (, 2017-07-28, ), (United States)]
# 6829  [8 July 2017, (, 2017-07-08, )]
# 6834  [31 August 2017, (, 2017-08-31, ), (, Venice, ), 14 September 2017, (, 2017-09-14, ), (Lebanon), 31 January 2018, (, 2018-01-31, ), (France)]
# 6849  [18 May 2017, (, 2017-05-18, ), (, Cannes, ), 1 June 2017, (, 2017-06-01, ), (Russia)]
# 6862  [2 September 2017, (, 2017-09-02, ), (, Venice, ), [2]]
# 7009  [July 5, 2018, (, 2018-07-05, ), (, Anime Expo, ), August 3, 2018, (, 2018-08-03, ), (Japan)]
# 7054  [13 May 2018, (, 2018-05-13, ), (, Cannes, ), 8 June 2018, (, 2018-06-08, ), (Japan)]
# 7058  [17 May 2018, (, 2018-05-17, ), (, Cannes, ), 20 September 2018, (, 2018-09-20, ), (Lebanon)]
# 7070  [10 May 2018, (, 2018-05-10, ), (, Cannes, ), 8 June 2018, (, 2018-06-08, ), (Poland), 31 August 2018, (, 2018-08-31, ), (United Kingdom), 24 October 2018, (, 2018-10-24, ), (France)]
#
#                                                 Running time  \
# 858   106 minutes
# 1342  101 minutes
# 1534  94 minutes
# 1888  126 minutes
# 3413  [86 Min, (Original Release), 95 Min, (Director's Cut)]
# 4238  77 minutes
# 4790  90 minutes
# 6393  103 minutes
# 6456  105 minutes
# 6613  103 minutes
# 6620  80 minutes
# 6661  76 minutes
# 6719  81 minutes
# 6829  103 minutes
# 6834  112 minutes
# 6849  127 minutes
# 6862  112 minutes
# 7009  96 minutes
# 7054  121 minutes
# 7058  126 minutes
# 7070  88 minutes
#
#                                           Country  \
# 858   [Taiwan, United States]
# 1342  NaN
# 1534  China
# 1888  France
# 3413  South Korea
# 4238  [United States, South Korea]
# 4790  [Israel, Germany, France]
# 6393  Japan
# 6456  Hong Kong
# 6613  [United States, [5], China, [5]]
# 6620  [China, United States]
# 6661  [United States, China]
# 6719  United States
# 6829  Japan
# 6834  [France, Lebanon]
# 6849  [Russia, France, Belgium, Germany, [3]]
# 6862  [Israel, Germany, France, Switzerland, [3]]
# 7009  Japan
# 7054  Japan
# 7058  Lebanon
# 7070  [Poland, France, United Kingdom]
#
#                          Language                                  Budget  \
# 858   [Mandarin Chinese, English]  $1 million
# 1342  NaN                          $6,000,000
# 1534  Mandarin                     NaN
# 1888  English                      [$90 million, [4], [5], [6], [7], [a]]
# 3413  [Korean, English]            NaN
# 4238  English                      $10 million
# 4790  Hebrew                       $2 million
# 6393  Japanese                     [¥1.15 billion, (, $10.5 million, )]
# 6456  Cantonese                    [US$, 36 million, [3]]
# 6613  [English, Mandarin]          $150 million
# 6620  [Chinese, English]           $60 million
# 6661  [English, Mandarin]          $5–10 million
# 6719  [Yiddish, English]           NaN
# 6829  Japanese                     NaN
# 6834  Lebanese Arabic              NaN
# 6849  Russian                      NaN
# 6862  Hebrew                       NaN
# 7009  Japanese                     NaN
# 7054  Japanese                     NaN
# 7058  [Arabic, Amharic]            $4 million
# 7070  [Polish, French]             €4.3 million
#
#                               Box office  \
# 858   $23.6 million
# 1342  NaN
# 1534  NaN
# 1888  $263.9 million
# 3413  NaN
# 4238  $13.7 million
# 4790  $11,125,849
# 6393  [¥3.85 billion, (, $36 million, )]
# 6456  $157,300,954
# 6613  $334.9 million
# 6620  $24.1 million
# 6661  $25.1 million
# 6719  $1.7 million
# 6829  [$, 41 million, [3]]
# 6834  $1.6 million
# 6849  $4.8 million
# 6862  $497,096
# 7009  $27,844,607
# 7054  $72.7 million
# 7058  $68.6 million
# 7070  $19.4 million
#
#                                                                Written by  \
# 858   [Ang Lee, Neil Peng, James Schamus]
# 1342  [Alistair MacLean, (story),, Alistair MacNeill, (novel)]
# 1534  [Wang Xiaobo, Zhang Yuan]
# 1888  NaN
# 3413  [Kim Moon-saeng, Park Jun-Yong]
# 4238  [Scott Clevenger, Chris Denk, Anurag Mehta, Timothy Wayne Peternel]
# 4790  Ari Folman
# 6393  NaN
# 6456  [Edmond Wong, Chan Tai-lee, Jil Leung]
# 6613  NaN
# 6620  NaN
# 6661  NaN
# 6719  [Alex Lipschultz, Musa Syeed, Joshua Z. Weinstein]
# 6829  NaN
# 6834  [Ziad Doueiri, Joelle Touma]
# 6849  NaN
# 6862  Samuel Maoz
# 7009  Yōsuke Kuroda
# 7054  Hirokazu Kore-eda
# 7058  NaN
# 7070  [Paweł Pawlikowski, Janusz Głowacki, Piotr Borkowski]
#
#                    Genre Theme music composer Country of origin  \
# 858   NaN                 NaN                  NaN
# 1342  [Action, Thriller]  John Scott           United States
# 1534  NaN                 NaN                  NaN
# 1888  NaN                 NaN                  NaN
# 3413  NaN                 NaN                  NaN
# 4238  NaN                 NaN                  NaN
# 4790  NaN                 NaN                  NaN
# 6393  NaN                 NaN                  NaN
# 6456  NaN                 NaN                  NaN
# 6613  NaN                 NaN                  NaN
# 6620  NaN                 NaN                  NaN
# 6661  NaN                 NaN                  NaN
# 6719  NaN                 NaN                  NaN
# 6829  NaN                 NaN                  NaN
# 6834  NaN                 NaN                  NaN
# 6849  NaN                 NaN                  NaN
# 6862  NaN                 NaN                  NaN
# 7009  NaN                 NaN                  NaN
# 7054  NaN                 NaN                  NaN
# 7058  NaN                 NaN                  NaN
# 7070  NaN                 NaN                  NaN
#
#      Original language(s)  \
# 858   NaN
# 1342  English
# 1534  NaN
# 1888  NaN
# 3413  NaN
# 4238  NaN
# 4790  NaN
# 6393  NaN
# 6456  NaN
# 6613  NaN
# 6620  NaN
# 6661  NaN
# 6719  NaN
# 6829  NaN
# 6834  NaN
# 6849  NaN
# 6862  NaN
# 7009  NaN
# 7054  NaN
# 7058  NaN
# 7070  NaN
#
#                                                                        Producer(s)  \
# 858   NaN
# 1342  [Boris Dmitrovic, (line producer), Mike Mihalic, (co-producer), Peter Snell]
# 1534  NaN
# 1888  NaN
# 3413  NaN
# 4238  NaN
# 4790  NaN
# 6393  NaN
# 6456  NaN
# 6613  NaN
# 6620  NaN
# 6661  NaN
# 6719  NaN
# 6829  NaN
# 6834  NaN
# 6849  NaN
# 6862  NaN
# 7009  NaN
# 7054  NaN
# 7058  NaN
# 7070  NaN
#
#               Editor(s) Production company(s) Original network  \
# 858   NaN                NaN                   NaN
# 1342  Eric Boyd-Perkins  J&M Entertainment     USA
# 1534  NaN                NaN                   NaN
# 1888  NaN                NaN                   NaN
# 3413  NaN                NaN                   NaN
# 4238  NaN                NaN                   NaN
# 4790  NaN                NaN                   NaN
# 6393  NaN                NaN                   NaN
# 6456  NaN                NaN                   NaN
# 6613  NaN                NaN                   NaN
# 6620  NaN                NaN                   NaN
# 6661  NaN                NaN                   NaN
# 6719  NaN                NaN                   NaN
# 6829  NaN                NaN                   NaN
# 6834  NaN                NaN                   NaN
# 6849  NaN                NaN                   NaN
# 6862  NaN                NaN                   NaN
# 7009  NaN                NaN                   NaN
# 7054  NaN                NaN                   NaN
# 7058  NaN                NaN                   NaN
# 7070  NaN                NaN                   NaN
#
#                           Original release  \
# 858   NaN
# 1342  [October 13, 1995, (, 1995-10-13, )]
# 1534  NaN
# 1888  NaN
# 3413  NaN
# 4238  NaN
# 4790  NaN
# 6393  NaN
# 6456  NaN
# 6613  NaN
# 6620  NaN
# 6661  NaN
# 6719  NaN
# 6829  NaN
# 6834  NaN
# 6849  NaN
# 6862  NaN
# 7009  NaN
# 7054  NaN
# 7058  NaN
# 7070  NaN
#
#                                                                                                  Productioncompanies   \
# 858   NaN
# 1342  NaN
# 1534  NaN
# 1888  NaN
# 3413  NaN
# 4238  NaN
# 4790  [Bridgit Folman Film Gang, Les Films d'Ici, Razor Film Produktion]
# 6393  NaN
# 6456  [Dreams Salon Entertainment Culture, Pegasus Motion Pictures, [1], Starbright Communications, Super Hero Films]
# 6613  NaN
# 6620  [Mandoo Pictures, Huayi Tencent Entertainment Company, Eracme Entertainment, Dream Factory Group]
# 6661  NaN
# 6719  NaN
# 6829  NaN
# 6834  NaN
# 6849  NaN
# 6862  NaN
# 7009  NaN
# 7054  NaN
# 7058  NaN
# 7070  NaN
#
#      Executive producer(s) Production location(s)  Distributor Picture format  \
# 858   NaN                   NaN                    NaN          NaN
# 1342  NaN                   NaN                    USA Network  Color
# 1534  NaN                   NaN                    NaN          NaN
# 1888  NaN                   NaN                    NaN          NaN
# 3413  NaN                   NaN                    NaN          NaN
# 4238  NaN                   NaN                    NaN          NaN
# 4790  NaN                   NaN                    NaN          NaN
# 6393  NaN                   NaN                    NaN          NaN
# 6456  NaN                   NaN                    NaN          NaN
# 6613  NaN                   NaN                    NaN          NaN
# 6620  NaN                   NaN                    NaN          NaN
# 6661  NaN                   NaN                    NaN          NaN
# 6719  NaN                   NaN                    NaN          NaN
# 6829  NaN                   NaN                    NaN          NaN
# 6834  NaN                   NaN                    NaN          NaN
# 6849  NaN                   NaN                    NaN          NaN
# 6862  NaN                   NaN                    NaN          NaN
# 7009  NaN                   NaN                    NaN          NaN
# 7054  NaN                   NaN                    NaN          NaN
# 7058  NaN                   NaN                    NaN          NaN
# 7070  NaN                   NaN                    NaN          NaN
#
#      Audio format Voices of Followed by Composer(s) Created by Preceded by  \
# 858   NaN          NaN       NaN         NaN         NaN        NaN
# 1342  Stereo       NaN       NaN         NaN         NaN        NaN
# 1534  NaN          NaN       NaN         NaN         NaN        NaN
# 1888  NaN          NaN       NaN         NaN         NaN        NaN
# 3413  NaN          NaN       NaN         NaN         NaN        NaN
# 4238  NaN          NaN       NaN         NaN         NaN        NaN
# 4790  NaN          NaN       NaN         NaN         NaN        NaN
# 6393  NaN          NaN       NaN         NaN         NaN        NaN
# 6456  NaN          NaN       NaN         NaN         NaN        NaN
# 6613  NaN          NaN       NaN         NaN         NaN        NaN
# 6620  NaN          NaN       NaN         NaN         NaN        NaN
# 6661  NaN          NaN       NaN         NaN         NaN        NaN
# 6719  NaN          NaN       NaN         NaN         NaN        NaN
# 6829  NaN          NaN       NaN         NaN         NaN        NaN
# 6834  NaN          NaN       NaN         NaN         NaN        NaN
# 6849  NaN          NaN       NaN         NaN         NaN        NaN
# 6862  NaN          NaN       NaN         NaN         NaN        NaN
# 7009  NaN          NaN       NaN         NaN         NaN        NaN
# 7054  NaN          NaN       NaN         NaN         NaN        NaN
# 7058  NaN          NaN       NaN         NaN         NaN        NaN
# 7070  NaN          NaN       NaN         NaN         NaN        NaN
#
#      Adaptation by Suggested by  \
# 858   NaN           NaN
# 1342  NaN           NaN
# 1534  NaN           NaN
# 1888  NaN           NaN
# 3413  NaN           NaN
# 4238  NaN           NaN
# 4790  NaN           NaN
# 6393  NaN           NaN
# 6456  NaN           NaN
# 6613  NaN           NaN
# 6620  NaN           NaN
# 6661  NaN           NaN
# 6719  NaN           NaN
# 6829  NaN           NaN
# 6834  NaN           NaN
# 6849  NaN           NaN
# 6862  NaN           NaN
# 7009  NaN           NaN
# 7054  NaN           NaN
# 7058  NaN           NaN
# 7070  NaN           NaN
#
#                                                                                                                                                                                                                                                                                                                                                       alt_titles  \
# 858   {'Mandarin': 'Xǐyàn', 'Traditional': '喜宴'}
# 1342  {'Also known as': 'Detonator II: Night Watch'}
# 1534  {'Mandarin': 'Dōng Gōng Xī Gōng', 'Simplified': '东宫西宫', 'Traditional': '東宮西宮'}
# 1888  {'French': 'Le Cinquième Élément'}
# 3413  {'Hangul': '원더풀 데이즈', 'McCune–Reischauer': 'Wŏndŏp‘ul teijŭ', 'Revised Romanization': 'Wondeopul deijeu'}
# 4238  {'Hangul': '파이 스토리', 'McCune–Reischauer': 'P‘ai sŭt‘ori', 'Revised Romanization': 'Pai seutori'}
# 4790  {'Original title': 'ואלס עם באשיר'}
# 6393  {'Hepburn': 'Omoide no Mānī', 'Japanese': '思い出のマーニー', 'Literally': 'Marnie of [my] Memories'}
# 6456  {'Cantonese': ['Jip', '6', 'Man', '6', 'Saam', '1'], 'Mandarin': 'Yè Wèn Sān', 'Simplified': '叶问3', 'Traditional': '葉問3'}
# 6613  {'Mandarin': 'Cháng Chéng', 'Simplified': '长城', 'Traditional': '長城'}
# 6620  {'Chinese': '摇滚藏獒'}
# 6661  {'Simplified': '我们诞生在中国', 'Traditional': '我們誕生在中國'}
# 6719  {'Yiddish': 'מנשה'}
# 6829  {'Hepburn': 'Meari to Majo no Hana', 'Japanese': 'メアリと魔女の花'}
# 6834  {'Arabic': 'قضية رقم ٢٣', 'Literally': 'Case No. 23', 'Romanized': 'Qadiyya raqm 23'}
# 6849  {'Romanized': 'Nelyubov', 'Russian': 'Нелюбовь'}
# 6862  {'Hebrew': 'פוֹקְסטְרוֹט'}
# 7009  {'Hepburn': 'Boku no Hīrō Akademia THE MOVIE: Futari no Hīrō', 'Japanese': ['僕のヒーローアカデミア THE MOVIE ～２人の', '.mw-parser-output ruby>rt,.mw-parser-output ruby>rtc{font-feature-settings:"ruby"1}.mw-parser-output ruby.large{font-size:250%}.mw-parser-output ruby.large>rt,.mw-parser-output ruby.large>rtc{font-size:.3em}', '英雄', '（', 'ヒーロー', '）', '～']}
# 7054  {'Hepburn': 'Manbiki Kazoku', 'Japanese': '万引き家族', 'Literally': 'Shoplifting Family'}
# 7058  {'Arabic': 'کفرناحوم‎'}
# 7070  {'Polish': 'Zimna wojna'}
#
#      Released Recorded Venue Length Label Director Producer Animation by  \
# 858   NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 1342  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 1534  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 1888  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 3413  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 4238  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 4790  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 6393  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 6456  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 6613  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 6620  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 6661  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 6719  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 6829  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 6834  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 6849  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 6862  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 7009  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 7054  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 7058  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
# 7070  NaN      NaN      NaN   NaN    NaN   NaN      NaN      NaN
#
#      Color process Screen story by
# 858   NaN           NaN
# 1342  NaN           NaN
# 1534  NaN           NaN
# 1888  NaN           NaN
# 3413  NaN           NaN
# 4238  NaN           NaN
# 4790  NaN           NaN
# 6393  NaN           NaN
# 6456  NaN           NaN
# 6613  NaN           NaN
# 6620  NaN           NaN
# 6661  NaN           NaN
# 6719  NaN           NaN
# 6829  NaN           NaN
# 6834  NaN           NaN
# 6849  NaN           NaN
# 6862  NaN           NaN
# 7009  NaN           NaN
# 7054  NaN           NaN
# 7058  NaN           NaN
# 7070  NaN           NaN

# %% [markdown]
# # 8.3.6 Create a Function to clean the data Part 2

# %%
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    # combine alternate titles into one list
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune-Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles

    # merge column names
    def change_column_name(old_name, new_name):
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Country of origin', 'Country')
    change_column_name('Directed by', 'Director')
    change_column_name('Distributed by', 'Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Length', 'Running time')
    change_column_name('Original release', 'Release date')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release Date')
    change_column_name('Release Date', 'Release date')
    change_column_name('Screen story by', 'Writer(s)')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Story by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Written by', 'Writer(s)')

    return movie

# %%
clean_movies = [clean_movie(movie) for movie in wiki_movies]
wiki_movies_df = pd.DataFrame(clean_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Created by',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'McCune–Reischauer',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Picture format',
#  'Preceded by',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Recorded',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Suggested by',
#  'Venue',
#  'Voices of',
#  'Writer(s)',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %% [markdown]
# # 8.3.7 Remove Duplicate Rows

# %%
wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')
print(len(wiki_movies_df))
wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
print(len(wiki_movies_df))
wiki_movies_df.head()
# Out:
# 7076
# 7033
#                                                              url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_Sweet             1990
# 2  https://en.wikipedia.org/wiki/Air_America_(film)               1990
# 3  https://en.wikipedia.org/wiki/Alice_(1990_film)                1990
# 4  https://en.wikipedia.org/wiki/Almost_an_Angel                  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/  After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/  Air America
# 3  https://www.imdb.com/title/tt0099012/  Alice
# 4  https://www.imdb.com/title/tt0099018/  Almost an Angel
#
#                                               Based on  \
# 0  [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thompson]
# 2  [Air America, by, Christopher Robbins]
# 3  NaN
# 4  NaN
#
#                                                                                                           Starring  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Presley, Lauren Holly, Morris Day, Robert Englund, Ed O'Neill]
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George Dickerson]
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, David Marshall Grant, Lane Smith]
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia Farrow, William Hurt, Keye Luke, Joe Mantegna, Bernadette Peters]
# 4  [Paul Hogan, Elias Koteas, Linda Kozlowski]
#
#           Narrated by  Cinematography  \
# 0  Andrew "Dice" Clay  Oliver Wood
# 1  NaN                 Mark Plummer
# 2  NaN                 Roger Deakins
# 3  NaN                 Carlo Di Palma
# 4  NaN                 Russell Boyd
#
#                                                                                                  Release date  \
# 0  [July 11, 1990, (, 1990-07-11, )]
# 1  [May 17, 1990, (, 1990-05-17, ), (Cannes Film Market), August 24, 1990, (, 1990-08-24, ), (United States)]
# 2  [August 10, 1990, (, 1990-08-10, )]
# 3  [December 25, 1990, (, 1990-12-25, )]
# 4  December 19, 1990
#
#   Running time        Country        Language       Budget        Box office  \
# 0  102 minutes  United States  English         $20 million  $21.4 million
# 1  114 minutes  United States  English         $6 million   $2.7 million
# 2  113 minutes  United States  [English, Lao]  $35 million  $57,718,089
# 3  106 minutes  United States  English         $12 million  $7,331,647
# 4  95 minutes   US             English         $25 million  $6,939,946 (USA)
#
#              Director         Distributor                       Editor(s)  \
# 0  Renny Harlin        20th Century Fox    Michael Tronick
# 1  James Foley         Avenue Pictures     Howard E. Smith
# 2  Roger Spottiswoode  TriStar Pictures    [John Bloom, Lois Freeman-Fox]
# 3  Woody Allen         Orion Pictures      Susan E. Morse
# 4  John Cornell        Paramount Pictures  David Stiven
#
#                Composer(s)                  Producer(s)  \
# 0  [Cliff Eidelman, Yello]  [Steve Perry, Joel Silver]
# 1  Maurice Jarre            [Ric Kidney, Robert Redlin]
# 2  Charles Gross            Daniel Melnick
# 3  NaN                      Robert Greenhut
# 4  Maurice Jarre            John Cornell
#
#                    Production company(s)                     Writer(s) Genre  \
# 0  Silver Pictures                        [David Arnott, James Cappe]   NaN
# 1  Avenue Pictures                        [James Foley, Robert Redlin]  NaN
# 2  [Carolco Pictures, IndieProd Company]  [John Eskow, Richard Rush]    NaN
# 3  NaN                                    Woody Allen                   NaN
# 4  NaN                                    Paul Hogan                    NaN
#
#   Original language(s) Original network Executive producer(s)  \
# 0  NaN                  NaN              NaN
# 1  NaN                  NaN              NaN
# 2  NaN                  NaN              NaN
# 3  NaN                  NaN              NaN
# 4  NaN                  NaN              NaN
#
#   Production location(s) Picture format Audio format Voices of Followed by  \
# 0  NaN                    NaN            NaN          NaN       NaN
# 1  NaN                    NaN            NaN          NaN       NaN
# 2  NaN                    NaN            NaN          NaN       NaN
# 3  NaN                    NaN            NaN          NaN       NaN
# 4  NaN                    NaN            NaN          NaN       NaN
#
#   Created by Preceded by Suggested by alt_titles Recorded Venue Label  \
# 0  NaN        NaN         NaN          NaN        NaN      NaN   NaN
# 1  NaN        NaN         NaN          NaN        NaN      NaN   NaN
# 2  NaN        NaN         NaN          NaN        NaN      NaN   NaN
# 3  NaN        NaN         NaN          NaN        NaN      NaN   NaN
# 4  NaN        NaN         NaN          NaN        NaN      NaN   NaN
#
#   Animation by Color process McCune–Reischauer    imdb_id
# 0  NaN          NaN           NaN               tt0098987
# 1  NaN          NaN           NaN               tt0098994
# 2  NaN          NaN           NaN               tt0099005
# 3  NaN          NaN           NaN               tt0099012
# 4  NaN          NaN           NaN               tt0099018

# %% [markdown]
# #### Remove Mostly Null Values

# %%
[[column,wiki_movies_df[column].isnull().sum()] for column in wiki_movies_df.columns]
# Out:
# [['url', 0],
#  ['year', 0],
#  ['imdb_link', 0],
#  ['title', 1],
#  ['Based on', 4852],
#  ['Starring', 184],
#  ['Narrated by', 6752],
#  ['Cinematography', 691],
#  ['Release date', 32],
#  ['Running time', 139],
#  ['Country', 236],
#  ['Language', 244],
#  ['Budget', 2295],
#  ['Box office', 1548],
#  ['Director', 0],
#  ['Distributor', 357],
#  ['Editor(s)', 548],
#  ['Composer(s)', 518],
#  ['Producer(s)', 202],
#  ['Production company(s)', 1678],
#  ['Writer(s)', 199],
#  ['Genre', 6923],
#  ['Original language(s)', 6875],
#  ['Original network', 6908],
#  ['Executive producer(s)', 6936],
#  ['Production location(s)', 6986],
#  ['Picture format', 6969],
#  ['Audio format', 6972],
#  ['Voices of', 7031],
#  ['Followed by', 7024],
#  ['Created by', 7023],
#  ['Preceded by', 7023],
#  ['Suggested by', 7032],
#  ['alt_titles', 7012],
#  ['Recorded', 7031],
#  ['Venue', 7032],
#  ['Label', 7031],
#  ['Animation by', 7031],
#  ['Color process', 7032],
#  ['McCune–Reischauer', 7031],
#  ['imdb_id', 0]]

# %%
wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]

# %% [markdown]
# # 8.3.8 Make a Plan to Convert and Parse the Data

# %%
wiki_movies_df.head(50)
# Out:
#                                                                          url  \
# 0   https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane
# 1   https://en.wikipedia.org/wiki/After_Dark,_My_Sweet
# 2   https://en.wikipedia.org/wiki/Air_America_(film)
# 3   https://en.wikipedia.org/wiki/Alice_(1990_film)
# 4   https://en.wikipedia.org/wiki/Almost_an_Angel
# 5   https://en.wikipedia.org/wiki/The_Ambulance
# 6   https://en.wikipedia.org/wiki/American_Dream_(film)
# 7   https://en.wikipedia.org/wiki/American_Ninja_4:_The_Annihilation
# 8   https://en.wikipedia.org/wiki/Andre%27s_Mother
# 9   https://en.wikipedia.org/wiki/Angel_Town_(film)
# 10  https://en.wikipedia.org/wiki/Another_48_Hrs.
# 11  https://en.wikipedia.org/wiki/Arachnophobia_(film)
# 12  https://en.wikipedia.org/wiki/Avalon_(1990_film)
# 13  https://en.wikipedia.org/wiki/Awakenings
# 14  https://en.wikipedia.org/wiki/Back_to_the_Future_Part_III
# 15  https://en.wikipedia.org/wiki/Bad_Influence_(film)
# 16  https://en.wikipedia.org/wiki/Basket_Case_2
# 17  https://en.wikipedia.org/wiki/Betsy%27s_Wedding
# 18  https://en.wikipedia.org/wiki/Bird_on_a_Wire_(film)
# 19  https://en.wikipedia.org/wiki/Blind_Faith_(1990_film)
# 20  https://en.wikipedia.org/wiki/Bloodfist_II
# 21  https://en.wikipedia.org/wiki/Blue_Steel_(1990_film)
# 22  https://en.wikipedia.org/wiki/The_Bonfire_of_the_Vanities_(film)
# 23  https://en.wikipedia.org/wiki/Bride_of_Re-Animator
# 24  https://en.wikipedia.org/wiki/Cadence_(film)
# 25  https://en.wikipedia.org/wiki/Cadillac_Man
# 26  https://en.wikipedia.org/wiki/Camp_Cucamonga
# 27  https://en.wikipedia.org/wiki/Captain_America_(1990_film)
# 28  https://en.wikipedia.org/wiki/Cartoon_All-Stars_to_the_Rescue
# 29  https://en.wikipedia.org/wiki/Catchfire
# 30  https://en.wikipedia.org/wiki/Challenger_(1990_film)
# 31  https://en.wikipedia.org/wiki/Checkered_Flag_(film)
# 32  https://en.wikipedia.org/wiki/Child_in_the_Night
# 33  https://en.wikipedia.org/wiki/Child%27s_Play_2
# 34  https://en.wikipedia.org/wiki/China_Cry
# 35  https://en.wikipedia.org/wiki/The_China_Lake_Murders
# 36  https://en.wikipedia.org/wiki/China_O%27Brien
# 37  https://en.wikipedia.org/wiki/Class_of_1999
# 38  https://en.wikipedia.org/wiki/Coins_in_the_Fountain
# 39  https://en.wikipedia.org/wiki/Come_See_the_Paradise
# 40  https://en.wikipedia.org/wiki/Coupe_de_Ville_(film)
# 41  https://en.wikipedia.org/wiki/Crash_and_Burn_(1990_film)
# 42  https://en.wikipedia.org/wiki/Crazy_People
# 43  https://en.wikipedia.org/wiki/Cry-Baby
# 44  https://en.wikipedia.org/wiki/Daddy%27s_Dyin%27:_Who%27s_Got_the_Will%3F
# 45  https://en.wikipedia.org/wiki/Dances_with_Wolves
# 46  https://en.wikipedia.org/wiki/The_Dark_Side_of_the_Moon_(1990_film)
# 47  https://en.wikipedia.org/wiki/Darkman
# 48  https://en.wikipedia.org/wiki/Daughter_of_Darkness_(1990_film)
# 49  https://en.wikipedia.org/wiki/Days_of_Thunder
#
#     year                              imdb_link  \
# 0   1990  https://www.imdb.com/title/tt0098987/
# 1   1990  https://www.imdb.com/title/tt0098994/
# 2   1990  https://www.imdb.com/title/tt0099005/
# 3   1990  https://www.imdb.com/title/tt0099012/
# 4   1990  https://www.imdb.com/title/tt0099018/
# 5   1990  https://www.imdb.com/title/tt0099026/
# 6   1990  https://www.imdb.com/title/tt0099028/
# 7   1990  https://www.imdb.com/title/tt0101326/
# 8   1990  https://www.imdb.com/title/tt0099037/
# 9   1990  https://www.imdb.com/title/tt0099039/
# 10  1990  https://www.imdb.com/title/tt0099044/
# 11  1990  https://www.imdb.com/title/tt0099052/
# 12  1990  https://www.imdb.com/title/tt0099073/
# 13  1990  https://www.imdb.com/title/tt0099077/
# 14  1990  https://www.imdb.com/title/tt0099088/
# 15  1990  https://www.imdb.com/title/tt0099091/
# 16  1990  https://www.imdb.com/title/tt0099108/
# 17  1990  https://www.imdb.com/title/tt0099128/
# 18  1990  https://www.imdb.com/title/tt0099141/
# 19  1990  https://www.imdb.com/title/tt0099148/
# 20  1990  https://www.imdb.com/title/tt0099155/
# 21  1990  https://www.imdb.com/title/tt0099160/
# 22  1990  https://www.imdb.com/title/tt0099165/
# 23  1990  https://www.imdb.com/title/tt0099180/
# 24  1990  https://www.imdb.com/title/tt0101531/
# 25  1990  https://www.imdb.com/title/tt0099204/
# 26  1990  https://www.imdb.com/title/tt0099212/
# 27  1990  https://www.imdb.com/title/tt0103923/
# 28  1990  https://www.imdb.com/title/tt0154129/
# 29  1990  https://www.imdb.com/title/tt0096875/
# 30  1990  https://www.imdb.com/title/tt0099237/
# 31  1990  https://www.imdb.com/title/tt0099245/
# 32  1990  https://www.imdb.com/title/tt0099252/
# 33  1990  https://www.imdb.com/title/tt0099253/
# 34  1990  https://www.imdb.com/title/tt0101578/
# 35  1990  https://www.imdb.com/title/tt0099259/
# 36  1990  https://www.imdb.com/title/tt0099260/
# 37  1990  https://www.imdb.com/title/tt0099277/
# 38  1990  https://www.imdb.com/title/tt0099284/
# 39  1990  https://www.imdb.com/title/tt0099291/
# 40  1990  https://www.imdb.com/title/tt0099310/
# 41  1990  https://www.imdb.com/title/tt0099313/
# 42  1990  https://www.imdb.com/title/tt0099316/
# 43  1990  https://www.imdb.com/title/tt0099329/
# 44  1990  https://www.imdb.com/title/tt0099342/
# 45  1990  https://www.imdb.com/title/tt0099348/
# 46  1990  https://www.imdb.com/title/tt0099364/
# 47  1990  https://www.imdb.com/title/tt0099365/
# 48  1990  https://www.imdb.com/title/tt0099368/
# 49  1990  https://www.imdb.com/title/tt0099371/
#
#                                    title  \
# 0   The Adventures of Ford Fairlane
# 1   After Dark, My Sweet
# 2   Air America
# 3   Alice
# 4   Almost an Angel
# 5   The Ambulance
# 6   American Dream
# 7   American Ninja 4: The Annihilation
# 8   Andre's Mother
# 9   Angel Town
# 10  Another 48 Hrs.
# 11  Arachnophobia
# 12  Avalon
# 13  Awakenings
# 14  Back to the Future Part III
# 15  Bad Influence
# 16  Basket Case 2
# 17  Betsy's Wedding
# 18  Bird on a Wire
# 19  Blind Faith
# 20  Bloodfist II
# 21  Blue Steel
# 22  The Bonfire of the Vanities
# 23  Bride of Re-Animator
# 24  Cadence
# 25  Cadillac Man
# 26  Camp Cucamonga
# 27  Captain America
# 28  Cartoon All-Stars to the Rescue
# 29  Catchfire
# 30  Challenger
# 31  Checkered Flag
# 32  Child in the Night
# 33  Child's Play 2
# 34  China Cry
# 35  The China Lake Murders
# 36  China O'Brien
# 37  Class of 1999
# 38  Coins in the Fountain
# 39  Come See the Paradise
# 40  Coupe de Ville
# 41  Crash and Burn
# 42  Crazy People
# 43  Cry-Baby
# 44  Daddy's Dyin' ...Who's Got the Will?
# 45  Dances with Wolves
# 46  The Dark Side of the Moon
# 47  Darkman
# 48  Daughter of Darkness
# 49  Days of Thunder
#
#                                                                              Based on  \
# 0   [Characters, by Rex Weiner]
# 1   [the novel, After Dark, My Sweet, by, Jim Thompson]
# 2   [Air America, by, Christopher Robbins]
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  [Characters by, Roger Spottiswoode, Walter Hill, Larry Gross, Steven E. de Souza]
# 11  NaN
# 12  NaN
# 13  [Awakenings, by, Oliver Sacks]
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  [Blind Faith, by, Joe McGinniss]
# 20  NaN
# 21  NaN
# 22  [The Bonfire of the Vanities, by, Tom Wolfe]
# 23  [Characters, by, H. P. Lovecraft]
# 24  NaN
# 25  NaN
# 26  NaN
# 27  [Captain America, by, Joe Simon, Jack Kirby]
# 28  NaN
# 29  NaN
# 30  NaN
# 31  NaN
# 32  NaN
# 33  [Characters, by Don Mancini]
# 34  [China Cry, by, Nora Lam, & Irene Burk Harrell]
# 35  NaN
# 36  NaN
# 37  NaN
# 38  NaN
# 39  NaN
# 40  NaN
# 41  NaN
# 42  NaN
# 43  NaN
# 44  NaN
# 45  [Dances with Wolves, by Michael Blake]
# 46  NaN
# 47  NaN
# 48  NaN
# 49  NaN
#
#                                                                                                                                                                                                                       Starring  \
# 0   [Andrew Dice Clay, Wayne Newton, Priscilla Presley, Lauren Holly, Morris Day, Robert Englund, Ed O'Neill]
# 1   [Jason Patric, Rachel Ward, Bruce Dern, George Dickerson]
# 2   [Mel Gibson, Robert Downey Jr., Nancy Travis, David Marshall Grant, Lane Smith]
# 3   [Alec Baldwin, Blythe Danner, Judy Davis, Mia Farrow, William Hurt, Keye Luke, Joe Mantegna, Bernadette Peters]
# 4   [Paul Hogan, Elias Koteas, Linda Kozlowski]
# 5   [Eric Roberts, James Earl Jones, Red Buttons, Megan Gallagher]
# 6   NaN
# 7   [Michael Dudikoff, David Bradley, James Booth, Dwayne Alexandre]
# 8   [Richard Thomas, Sada Thompson, Sylvia Sidney]
# 9   [Olivier Gruner, Theresa Saldana, Frank Aragon, Tony Valentino, Peter Kwong, Mike Moroff]
# 10  [Eddie Murphy, Nick Nolte, Brion James, Ed O'Ross, Andrew Divoff]
# 11  [Jeff Daniels, Julian Sands, Harley Jane Kozak, John Goodman]
# 12  [Armin Mueller-Stahl, Elizabeth Perkins, Joan Plowright, Aidan Quinn]
# 13  [Robert De Niro, Robin Williams, John Heard, Julie Kavner, Penelope Ann Miller, Max von Sydow]
# 14  [Michael J. Fox, Christopher Lloyd, Mary Steenburgen, Thomas F. Wilson, Lea Thompson]
# 15  [Rob Lowe, James Spader]
# 16  Kevin Van Hentenryck
# 17  [Alan Alda, Joey Bishop, Madeline Kahn, Catherine O'Hara, Joe Pesci, Ally Sheedy, Burt Young, Molly Ringwald]
# 18  [Mel Gibson, Goldie Hawn, David Carradine, Bill Duke]
# 19  [Robert Urich, Joanna Kerns, David Barry Gray, Jay Underwood, Johnny Galecki]
# 20  [Don Wilson, Maurice Smith, James Warring, Timothy Baker, Richard Hill]
# 21  [Jamie Lee Curtis, Ron Silver, Clancy Brown, Elizabeth Peña, Louise Fletcher]
# 22  [Tom Hanks, Bruce Willis, Melanie Griffith, Morgan Freeman]
# 23  [Jeffrey Combs, Bruce Abbott, Fabiana Udenio, Kathleen Kinmont]
# 24  [Charlie Sheen, Martin Sheen, Laurence Fishburne, Michael Beach, Ramon Estevez]
# 25  [Robin Williams, Tim Robbins, Pamela Reed, Fran Drescher]
# 26  [John Ratzenberger, Brian Robbins, Jennifer Aniston, Chad Allen, Candace Cameron, Danica McKellar, Josh Saviano, Tasha Scott, Jaleel White, Johnny Galecki, Dorothy Lyman, Richard Herd, Sherman Hemsley, G. Gordon Liddy]
# 27  [Matt Salinger, Ronny Cox, Scott Paulin, Ned Beatty, Darren McGavin, Francesca Neri, Michael Nouri]
# 28  NaN
# 29  [Jodie Foster, Dennis Hopper, Fred Ward, Vincent Price]
# 30  [Karen Allen, Barry Bostwick, Richard Jenkins, Joe Morton, Keone Young, Brian Kerwin, Julie Fulton, Kale Browne, Kristin Bond, Angela Bassett]
# 31  NaN
# 32  [JoBeth Williams, Tom Skerritt, Elijah Wood, Darren McGavin, Season Hubley]
# 33  [Alex Vincent, Jenny Agutter, Gerrit Graham, Christine Elise, Grace Zabriskie]
# 34  [Julia Nickson-Soul, France Nuyen, James Shigeta]
# 35  [Isaac Allan, Tom Skerritt, Michael Parks]
# 36  [Cynthia Rothrock, Richard Norton, Keith Cooke, Doug Wright, Nijel, Arturo Rivera]
# 37  [Bradley Gregg, Traci Lind, John P. Ryan, Pam Grier, Joshua Miller, Stacy Keach, Malcolm McDowell]
# 38  [Loni Anderson, Stepfanie Kramer, Shanna Reed, Carl Weintraub, Stuart Wilson, Anthony Newley]
# 39  [Dennis Quaid, Tamlyn Tomita, Sab Shimono, Shizuko Hoshi]
# 40  [Patrick Dempsey, Arye Gross, Daniel Stern, Annabeth Gish, Rita Taggart, Joseph Bologna, Alan Arkin]
# 41  [Paul Ganus, Megan Ward, Jack McGee, Eva LaRue]
# 42  [Dudley Moore, Daryl Hannah, Paul Reiser]
# 43  [Johnny Depp, Amy Locane, Susan Tyrrell, Iggy Pop, Ricki Lake, Traci Lords, Polly Bergen]
# 44  [Beau Bridges, Beverly D'Angelo, Tess Harper, Judge Reinhold, Amy Wright, Patrika Darbo, Molly McClure, Keith Carradine]
# 45  [Kevin Costner, Mary McDonnell, Graham Greene, Rodney Grant]
# 46  [Robert Sampson, Will Bledsoe, Joe Turkel, Camilla More, John Diehl, Wendy MacDonald, Alan Blumenfeld]
# 47  [Liam Neeson, Frances McDormand, Colin Friels, Larry Drake]
# 48  [Anthony Perkins, Mia Sara, Robert Reynolds, Dezsõ Garas, Jack Coleman]
# 49  [Tom Cruise, Robert Duvall, Randy Quaid, Nicole Kidman, Michael Rooker, John C. Reilly, Cary Elwes]
#
#                                    Cinematography  \
# 0   Oliver Wood
# 1   Mark Plummer
# 2   Roger Deakins
# 3   Carlo Di Palma
# 4   Russell Boyd
# 5   Jacques Haitkin
# 6   [Tom Hurwitz, Mathieu Roberts, Nesya Shapiro]
# 7   NaN
# 8   Bobby Bukowski
# 9   John LeBlanc
# 10  Matthew F. Leonetti
# 11  Mikael Salomon
# 12  Allen Daviau
# 13  Miroslav Ondricek
# 14  Dean Cundey
# 15  Robert Elswit
# 16  Robert M. Baldwin
# 17  Kelvin Pike
# 18  Robert Primes
# 19  Chuck Arnold
# 20  Bruce Dorfman
# 21  Amir Mokri
# 22  Vilmos Zsigmond
# 23  Rick Fichter
# 24  Richard Leiterman
# 25  David Gribble
# 26  Peter Smokler
# 27  Philip Alan Waters
# 28  NaN
# 29  Edward Lachman
# 30  NaN
# 31  NaN
# 32  Gerald Hirschfeld
# 33  Stefan Czapsky
# 34  David Worth
# 35  Geoffrey Schaaf
# 36  Kent L. Wakeford
# 37  Mark Irwin
# 38  NaN
# 39  Michael Seresin
# 40  Reynaldo Villalobos
# 41  Mark Ahlberg
# 42  Victor J. Kemper
# 43  David Insley
# 44  Paul Elliott
# 45  Dean Semler
# 46  NaN
# 47  Bill Pope
# 48  Iván Márk
# 49  Ward Russell
#
#                                                                                                        Release date  \
# 0   [July 11, 1990, (, 1990-07-11, )]
# 1   [May 17, 1990, (, 1990-05-17, ), (Cannes Film Market), August 24, 1990, (, 1990-08-24, ), (United States)]
# 2   [August 10, 1990, (, 1990-08-10, )]
# 3   [December 25, 1990, (, 1990-12-25, )]
# 4   December 19, 1990
# 5   [March 22, 1990, (, 1990-03-22, )]
# 6   [October 6, 1990, (, 1990-10-06, ), (, New York Film Festival, )]
# 7   [March 8, 1991, (, 1991-03-08, )]
# 8   [March 7, 1990, (, 1990-03-07, )]
# 9   [February 23, 1990 (, USA, )]
# 10  [June 8, 1990, (, 1990-06-08, )]
# 11  [July 18, 1990, (, 1990-07-18, )]
# 12  [October 5, 1990, (, 1990-10-05, ), (United States)]
# 13  [December 20, 1990 (limited U.S.), January 11, 1991 (wide U.S.)]
# 14  [May 25, 1990, (, 1990-05-25, )]
# 15  March 9, 1990
# 16  [March 2, 1990, (, 1990-03-02, )]
# 17  [June 22, 1990, (, 1990-06-22, )]
# 18  [May 18, 1990, (, 1990-05-18, )]
# 19  February 11, 1990
# 20  [October 12, 1990, (, 1990-10-12, )]
# 21  [January 1990, (, 1990-01, ), (, Sundance Film Festival, ), March 16, 1990, (, 1990-03-16, )]
# 22  [December 21, 1990, (, 1990-12-21, )]
# 23  [September 8, 1990, (, 1990-09-08, ), (, TIFF, ), February 22, 1991, (, 1991-02-22, )]
# 24  [1990, (, 1990, ), (Deauville Film Festival), January 18, 1990, (, 1990-01-18, ), (U.S.)]
# 25  [May 18, 1990, (, 1990-05-18, )]
# 26  September 23, 1990
# 27  [December 14, 1990, (, 1990-12-14, ), (United Kingdom), July 22, 1992, (, 1992-07-22, ), (United States)]
# 28  [April 21, 1990, (, 1990-04-21, ), (USA), June 22, 1990, (, 1990-06-22, ), (UK)]
# 29  [April 3, 1990, (, 1990-04-03, )]
# 30  [February 25, 1990, (, 1990-02-25, )]
# 31  [1990, (, 1990, ), [1]]
# 32  May 1, 1990
# 33  [November 9, 1990, (, 1990-11-09, )]
# 34  [November 2, 1990, (, 1990-11-02, ), (USA)]
# 35  [January 31, 1990, (, 1990-01-31, )]
# 36  [1988, (, 1988, )]
# 37  May 11, 1990
# 38  [September 28, 1990, (, 1990-09-28, )]
# 39  [December 23, 1990, (, 1990-12-23, )]
# 40  [March 9, 1990, (, 1990-03-09, )]
# 41  [September 1990, (, 1990-09, )]
# 42  [April 13, 1990, (, 1990-04-13, ), (U.S.)]
# 43  [March 14, 1990, (, 1990-03-14, ), (Baltimore), April 6, 1990, (, 1990-04-06, ), (United States)]
# 44  [May 4, 1990, (, 1990-05-04, )]
# 45  [October 19, 1990, (, 1990-10-19, ), (, Uptown Theater, ), November 9, 1990, (, 1990-11-09, ), (United States)]
# 46  [1990, (, 1990, )]
# 47  [August 24, 1990, (, 1990-08-24, )]
# 48  [January 26, 1990, (, 1990-01-26, )]
# 49  [June 27, 1990, (, 1990-06-27, )]
#
#    Running time                          Country                   Language  \
# 0   102 minutes  United States                    English
# 1   114 minutes  United States                    English
# 2   113 minutes  United States                    [English, Lao]
# 3   106 minutes  United States                    English
# 4   95 minutes   US                               English
# 5   95 minutes   United States                    English
# 6   100 minutes  [United States, United Kingdom]  English
# 7   99 minutes   [United States, Lesotho]         English
# 8   50 minutes   United States                    English
# 9   102 min      United States                    English
# 10  93 minutes   United States                    English
# 11  110 minutes  United States                    English
# 12  126 minutes  United States                    English
# 13  121 minutes  United States                    English
# 14  118 minutes  United States                    English
# 15  99 minutes   United States                    English
# 16  90 minutes   NaN                              English
# 17  94 minutes   United States                    English
# 18  110 minutes  United States                    English
# 19  190 minutes  United States                    NaN
# 20  85 minutes   United States                    English
# 21  102 minutes  United States                    English
# 22  126 minutes  United States                    English
# 23  96 minutes   United States                    English
# 24  97 minutes   United States                    English
# 25  97 minutes   United States                    English
# 26  93 min       United States                    NaN
# 27  97 minutes   [Yugoslavia, United States]      English
# 28  32 min.      United States                    NaN
# 29  98 minutes   United States                    English
# 30  NaN          United States                    NaN
# 31  95 minutes   NaN                              English
# 32  98 minutes   United States                    NaN
# 33  84 minutes   United States                    English
# 34  101 min      USA                              English
# 35  97 min       United States                    NaN
# 36  86 minutes   NaN                              English
# 37  99 minutes   United States                    English
# 38  97 minutes   NaN                              NaN
# 39  138 minutes  United States                    English
# 40  99 minutes   United States                    English
# 41  85 minutes   United States                    English
# 42  91 min.      United States                    English
# 43  85 minutes   United States                    English
# 44  95 minutes   United States                    English
# 45  181 minutes  United States                    [English, Lakota, Pawnee]
# 46  NaN          United States                    English
# 47  95 minutes   United States                    English
# 48  93 minutes   United States                    NaN
# 49  108 minutes  United States                    English
#
#                                  Budget                     Box office  \
# 0   $20 million                          $21.4 million
# 1   $6 million                           $2.7 million
# 2   $35 million                          $57,718,089
# 3   $12 million                          $7,331,647
# 4   $25 million                          $6,939,946 (USA)
# 5   NaN                                  NaN
# 6   NaN                                  NaN
# 7   NaN                                  NaN
# 8   NaN                                  NaN
# 9   NaN                                  $855,810
# 10  $50 million                          $195.3 million
# 11  $22 million                          $53.2 million
# 12  NaN                                  $15.7 million
# 13  $29 million                          $52.1 million
# 14  $40 million                          $244.5 million
# 15  $7 million                           $12,626,043
# 16  [$2,500,000, [, citation needed, ]]  NaN
# 17  NaN                                  $19,740,070
# 18  $20 million                          $138,697,012
# 19  NaN                                  NaN
# 20  NaN                                  $1,292,323
# 21  NaN                                  $8.2 million
# 22  $47 million                          $15.6 million
# 23  NaN                                  NaN
# 24  NaN                                  $2,070,871
# 25  $15 million                          $27.6 million (United States)
# 26  NaN                                  NaN
# 27  $10 million                          $10,173
# 28  NaN                                  NaN
# 29  $10 million                          $5 million
# 30  NaN                                  NaN
# 31  NaN                                  NaN
# 32  NaN                                  NaN
# 33  $13 million                          $35.8 million
# 34  NaN                                  [US$, 4,212,828]
# 35  NaN                                  NaN
# 36  NaN                                  NaN
# 37  $5.2 million                         $2.4 million
# 38  NaN                                  NaN
# 39  $17.5 million                        $947,306
# 40  NaN                                  $715,983
# 41  NaN                                  NaN
# 42  US$18 million                        US$13,236,513
# 43  $12 million                          $8.3 million
# 44  $4 million                           $1,373,728
# 45  $22 million                          $424.2 million
# 46  NaN                                  NaN
# 47  $16 million                          $48.8 million
# 48  NaN                                  NaN
# 49  $60 million                          $157.9 million
#
#                                                                                   Director  \
# 0   Renny Harlin
# 1   James Foley
# 2   Roger Spottiswoode
# 3   Woody Allen
# 4   John Cornell
# 5   Larry Cohen
# 6   [Barbara Kopple, Co-directors:, Cathy Caplan, Thomas Haneke, Lawrence Silk]
# 7   Cedric Sundstrom
# 8   Deborah Reinisch
# 9   Eric Karson
# 10  Walter Hill
# 11  Frank Marshall
# 12  Barry Levinson
# 13  Penny Marshall
# 14  Robert Zemeckis
# 15  Curtis Hanson
# 16  Frank Henenlotter
# 17  Alan Alda
# 18  John Badham
# 19  Paul Wendkos
# 20  Andy Blumenthal
# 21  Kathryn Bigelow
# 22  Brian De Palma
# 23  Brian Yuzna
# 24  Martin Sheen
# 25  Roger Donaldson
# 26  Roger Duchowny
# 27  Albert Pyun
# 28  [Milton Gray, Marsh Lamore, Bob Shellhorn, Mike Svayko, Karen Peterson, (supervising)]
# 29  [Dennis Hopper, (as, Alan Smithee, )]
# 30  Ben Jordan
# 31  [John Glen, Michael Levine]
# 32  Mike Robe
# 33  John Lafia
# 34  James F. Collier
# 35  Alan Metzger
# 36  Robert Clouse
# 37  Mark L. Lester
# 38  Tony Wharmby
# 39  Alan Parker
# 40  Joe Roth
# 41  Charles Band
# 42  [Tony Bill, Barry L. Young (commercials)]
# 43  John Waters
# 44  Jack Fisk
# 45  Kevin Costner
# 46  D.J. Webster
# 47  Sam Raimi
# 48  Stuart Gordon
# 49  Tony Scott
#
#                                                                                                                                           Distributor  \
# 0   20th Century Fox
# 1   Avenue Pictures
# 2   TriStar Pictures
# 3   Orion Pictures
# 4   Paramount Pictures
# 5   Triumph Releasing Corporation
# 6   Prestige Films
# 7   Cannon Group
# 8   Public Broadcasting Service
# ...
# 35  Dana Kaproff
# 36  [David Wheatley, Paul Antonelli]
# 37  Michael Hoenig
# 38  Nan Schwartz
# 39  Randy Edelman
# 40  James Newton Howard
# 41  Richard Band
# 42  Cliff Eidelman
# 43  Patrick Williams
# 44  David McHugh
# 45  John Barry
# 46  [Philip Davies, Mark Ryder]
# 47  Danny Elfman
# 48  Colin Towns
# 49  Hans Zimmer
#
#                                                                                                Producer(s)  \
# 0   [Steve Perry, Joel Silver]
# 1   [Ric Kidney, Robert Redlin]
# 2   Daniel Melnick
# 3   Robert Greenhut
# 4   John Cornell
# 5   [Larry Cohen, Moctesuma Esparza, Robert Katz]
# 6   [Arthur Cohn, Barbara Kopple]
# 7   Ovidio G Assonitis
# 8   [Sarah Green, Deborah Reinisch]
# 9   [Ash R. Shah, Eric Karson]
# 10  [Lawrence Gordon, Robert D. Wachs]
# 11  [Kathleen Kennedy, Richard Vane]
# 12  [Mark Johnson, Barry Levinson]
# 13  [Walter F. Parkes, Lawrence Lasker]
# 14  [Neil Canton, Bob Gale]
# 15  Steve Tisch
# 16  Edgar Ievins
# 17  [Martin Bregman, Louis A. Stroller]
# 18  Rob Cohen
# 19  [Susan Baerwald (executive producer), Dan Wigutow (executive producer), Daniel Franklin (co-producer)]
# 20  [New Horizons, Concorde Pictures, (, Roger Corman, Catherine Cyran, Cirio H. Santiago, )]
# 21  [Edward R. Pressman, Oliver Stone, Lawrence Kasanoff]
# 22  Brian De Palma
# 23  Brian Yuzna
# 24  [Timothy Gamble, Frank Giustra, Peter E. Strauss]
# 25  [Roger Donaldson, Charles Roven]
# 26  [Scott Maitland (co-producer), Bennett Tramer (supervising producer)]
# 27  [Joseph Calamari, Menahem Golan, Tom Karnowski, Stan Lee]
# 28  Buzz Potamkin
# 29  Dick Clark
# 30  [George Englund, Courtney Pledger, Debbie Robins]
# 31  James Margellos
# 32  [Ian Martin, John Perrin Flynn (co-producer), Benjamin A. Weissman (co-producer)]
# 33  David Kirschner
# 34  Don L. Parker
# 35  [William Beaudine Jr., Beth Tate (co-producer)]
# 36  [Fred Weintraub, Sandra Weintraub]
# 37  Mark L. Lester
# 38  Joseph B. Wallenstein
# 39  [Robert F. Colesberry, Nellie Nugiel]
# 40  [James G. Robinson, Mike Binder]
# 41  [David DeCoteau, John Schouweiler]
# 42  [Thomas Brand, Robert K. Weiss]
# 43  Rachel Talalay
# 44  [Steve Golin, Monty Montgomery]
# 45  [Jim Wilson, Kevin Costner]
# 46  [Keith Walley, D.J. Webster]
# 47  Robert Tapert
# 48  Andras Hamori
# 49  [Don Simpson, Jerry Bruckheimer]
#
#                                                           Production company(s)  \
# 0   Silver Pictures
# 1   Avenue Pictures
# 2   [Carolco Pictures, IndieProd Company]
# 3   NaN
# 4   NaN
# 5   Epic Productions
# 6   [Cabin Creek, Catholic Communication Campaign, Channel 4 Films]
# 7   NaN
# 8   NaN
# 9   NaN
# 10  Eddie Murphy Productions
# 11  [Hollywood Pictures, Amblin Entertainment, Tangled Web Productions]
# 12  Baltimore Pictures
# 13  Lasker/Parkes Productions
# 14  [Amblin Entertainment, [1], Universal Pictures, [1]]
# 15  Epic Productions
# 16  NaN
# 17  Touchstone Pictures
# 18  [Interscope Communications, The Badham/Cohen Group]
# 19  NBC Productions
# 20  NaN
# 21  [Lightning Pictures, Mack-Taylor Productions, Precision Films]
# 22  NaN
# 23  Wild Street Pictures
# 24  NaN
# 25  NaN
# 26  [NBC Productions, Richmel Productions]
# 27  [Marvel Entertainment Group, Jadran Film, 21st Century Film Corporation]
# 28  [Southern Star Productions, Wang Film Productions, (animation)]
# 29  NaN
# 30  NaN
# 31  NaN
# 32  [Allied Communications, Jayhawk Productions, Mike Robe Productions]
# 33  Living Doll Productions
# 34  Parakletus, TBN Films
# 35  [MCA Television Entertainment, Papazian-Hirsch Entertainment International]
# 36  NaN
# 37  NaN
# 38  NaN
# 39  NaN
# 40  Morgan Creek Productions
# 41  Full Moon Entertainment
# 42  NaN
# 43  Imagine Entertainment
# 44  [Metro-Goldwyn-Mayer, Propaganda Films]
# 45  Tig Productions
# 46  NaN
# 47  Renaissance Pictures
# 48  [Accent Entertainment Corporation, King Phoenix Entertainment]
# 49  Don Simpson/Jerry Bruckheimer Productions
#
#                                                             Writer(s)  \
# 0   [David Arnott, James Cappe]
# 1   [James Foley, Robert Redlin]
# 2   [John Eskow, Richard Rush]
# 3   Woody Allen
# 4   Paul Hogan
# 5   Larry Cohen
# 6   NaN
# 7   David Geeves
# 8   Terrence McNally
# 9   S. Warren
# 10  Fred Braughton
# 11  [Don Jakoby, Al Williams]
# 12  Barry Levinson
# 13  Steven Zaillian
# 14  [Robert Zemeckis, Bob Gale]
# 15  David Koepp
# 16  Frank Henenlotter
# 17  Alan Alda
# 18  [Louis Venosta, David Seltzer]
# 19  Joe McGinniss
# 20  Catherine Cyran
# 21  [Kathryn Bigelow, Eric Red, [1]]
# 22  Michael Cristofer
# 23  [Rick Fry, Woody Keith, Brian Yuzna]
# 24  Dennis Shryack
# 25  Ken Friedman
# 26  [Bennett Tramer (Story & teleplay), Rich Melcombe, (Story)]
# 27  [Stephen Tolkin, Lawrence Block]
# 28  [Duane Poole, Tom Swale]
# 29  [Rachel Kronstadt Mann, Ann Louise Bardach, Alex Cox, Tod Davies]
# 30  George Englund
# 31  [Clayton Frohman, E.F. Wallengren, Jason Brett]
# 32  Michael Petryni
# 33  Don Mancini
# 34  James F. Collier
# 35  N.D. Schreiner
# 36  Sandra Weintraub
# 37  Mark L. Lester
# 38  Lindsay Harrison
# 39  Alan Parker
# 40  Mike Binder
# 41  J. S. Cardone
# 42  Mitch Markowitz
# 43  John Waters
# 44  Del Shores
# 45  Michael Blake
# 46  [Carey Hayes, Chad Hayes]
# 47  Sam Raimi
# 48  Andrew Laskos
# 49  [Robert Towne, Tom Cruise]
#
#       imdb_id
# 0   tt0098987
# 1   tt0098994
# 2   tt0099005
# 3   tt0099012
# 4   tt0099018
# 5   tt0099026
# 6   tt0099028
# 7   tt0101326
# 8   tt0099037
# 9   tt0099039
# 10  tt0099044
# 11  tt0099052
# 12  tt0099073
# 13  tt0099077
# 14  tt0099088
# 15  tt0099091
# 16  tt0099108
# 17  tt0099128
# 18  tt0099141
# 19  tt0099148
# 20  tt0099155
# 21  tt0099160
# 22  tt0099165
# 23  tt0099180
# 24  tt0101531
# 25  tt0099204
# 26  tt0099212
# 27  tt0103923
# 28  tt0154129
# 29  tt0096875
# 30  tt0099237
# 31  tt0099245
# 32  tt0099252
# 33  tt0099253
# 34  tt0101578
# 35  tt0099259
# 36  tt0099260
# 37  tt0099277
# 38  tt0099284
# 39  tt0099291
# 40  tt0099310
# 41  tt0099313
# 42  tt0099316
# 43  tt0099329
# 44  tt0099342
# 45  tt0099348
# 46  tt0099364
# 47  tt0099365
# 48  tt0099368
# 49  tt0099371

# %%
wiki_movies_df.dtypes
# Out:
# url                      object
# year                     int64
# imdb_link                object
# title                    object
# Based on                 object
# Starring                 object
# Cinematography           object
# Release date             object
# Running time             object
# Country                  object
# Language                 object
# Budget                   object
# Box office               object
# Director                 object
# Distributor              object
# Editor(s)                object
# Composer(s)              object
# Producer(s)              object
# Production company(s)    object
# Writer(s)                object
# imdb_id                  object
# dtype: object

# %%
#Let's look at rows where box office is actually defined:
box_office = wiki_movies_df['Box office'].dropna()
box_office.size
# Out:
# 5485

# %%
#Regex will only work on strings...
#By using the apply() method, we can see which values are 
# not strings on box_office series

def is_not_a_string(x):
    return type(x) != str

box_office[box_office.map(is_not_a_string)]
# Out:
# 34      [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74      [$6,488,144, (US), [1]]
# 126     [US$1,531,489, (domestic)]
# 130     [US$, 4,803,039]
#               ...
# 6980    [$99.6, million, [4], [5]]
# 6994    [$365.6, million, [1]]
# 6995    [$53.8, million]
# 7015    [$435, million, [7]]
# 7048    [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
#However, we don't really need to reuse the function, so that was kind of unnecessary.
#It's easier to just use lambda, since we don't need to reuse it later etc.

#So, instead of having to write:
# def is_not_a_string(x):
#    return type(x) != str

#We could just use:
# lambda x: type(x) != str

# So let's do that:

box_office[box_office.map(lambda x: type(x) != str)]
# Out:
# 34      [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74      [$6,488,144, (US), [1]]
# 126     [US$1,531,489, (domestic)]
# 130     [US$, 4,803,039]
#               ...
# 6980    [$99.6, million, [4], [5]]
# 6994    [$365.6, million, [1]]
# 6995    [$53.8, million]
# 7015    [$435, million, [7]]
# 7048    [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
#In the box office column, there are lots of lists.  We don't want that.
#So we'll use .join BUT we need to add a space between each thing in the list, like this:
#If the value is not a list, we'll just keep that value in the box office column as it is.
#Recall apply would work on the whole dataframe but we're just using it for one column here
#I guess we could've also just used .map since that would work on a singe column as well.


box_office = box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)
box_office[34]
# Out:
# 'US$ 4,212,828'

# %%
# add "import re" to the top of the notebook (see top of notebook)

# %% [markdown]
# # 8.3.9 Write Regular Expressions

# %% [markdown]
# # 8.3.10 Write Regular Expressions

# %%
#NOTE, here we'll check for matches (using regex) of values in the column "box_office"
# that have the basic form like:   ""$123.4 million" (or billion)

# 1. A dollar sign
# 2. An arbitrary (but non-zero) number of digits
# 3. An optional decimal point
# 4. An arbitrary (but possibly zero) number of more digits
# 5. A space (maybe more than one)
# 6. The word "million" or "billion"

form_one = r'\$\d+\.?\d*\s*[mb]illion'

# %%
#Now see how many times it happens in the column.  Note, we'll use the flags argument to ignore case.
box_office.str.contains(form_one, flags=re.IGNORECASE).sum()
# Out:
# 3896

# %%
#Create the second form to search for matches down the column.  
# (Note, this is just basic number form with $:  $123,456,789)

# 1. A dollar sign
# 2. A group of one to three digits
# 3. At least one group starting with a comma and followed by exactly three digits

form_two = r'\$\d{1,3}(?:,\d{3})+'

#Like before, find the sum and ignore case:
box_office.str.contains(form_two, flags=re.IGNORECASE).sum()
# Out:
# 1544

# %%
matches_form_one = box_office.str.contains(form_one, flags=re.IGNORECASE)
matches_form_two = box_office.str.contains(form_two, flags=re.IGNORECASE)

# %%
#NOW, we can check to see which values do NOT match our two forms 
#  "$123.4 million" (or billion), and "$123,456,789."

#NOTE, the tilda means "not" and the ampersand means "and".  (The | means "or" but we don't need that one)
#So, if the value does NOT match form one AND it doesn't match form two:

box_office[~matches_form_one & ~matches_form_two]
# Out:
# 34      US$ 4,212,828
# 79      $335.000
# 110     $4.35-4.37 million
# 130     US$ 4,803,039
# 600     $5000 (US)
# 731     $ 11,146,270
# 957     $ 50,004
# 1070    35,254,617
# 1147    $ 407,618 (U.S.) (sub-total) [1]
# 1446    $ 11,829,959
# 1480    £3 million
# 1611    $520.000
# 1865    ¥1.1 billion
# 2032    N/A
# 2091    $309
# 2130    US$ 171.8 million [9]
# 2257    US$ 3,395,581 [1]
# 2263    $ 1,223,034 ( domestic )
# 2347    $282.175
# 2638    $ 104,883 (US sub-total)
# 2665    926,423 admissions (France)
# 2697    $ 1.7 million (US) (sub-total)
# 2823    $414.000
# 2924    $621.000
# 3088    $32 [2] –33.1 million [1]
# 3631    TBA
# 3859    $38.9–40.3 million
# 3879    CN¥3.650 million (China)
# 4116    £7,385,434
# 4123    $161.000
# 4261    $20.7–23.9 million
# 4306    $20-30
# 4492    $47.7 millon
# 4561    $45.2k (only in Turkey)
# 4662    USD$ 8.2 million [2]
# 5362    $ 142 million [3]
# 5447    £2.56
# 5784    413 733$
# 6013    Unknown
# 6145    $17.5–18.4 million
# 6234    $41.8–41.9 million
# 6369    $111k
# 6370    $588
# 6593    less than $372
# 6829    $ 41 million [3]
# 6843    8 crore
# 6904    $6.9 millon
# Name: Box office, dtype: object

# %%
#Now, how can we catch some of those values (above) we missed?  Well we try by addressing these:

#1. Some values have spaces in between the dollar sign and the number.
    # So add a s* after the dollar sign in case there's a space.
#2. Some values use a period as a thousands separator, not a comma.
    # So add a [,\.] to say "either a comma or a period.  NOTE the backslash is so period becomes literal.
    # ALSO, add (?!\s[mb]illion) bc you don't want to catch million or billion after a number like 1.234 aka 1,234
#3. Some values are given as a range.
    # Not a perfect solution but just replace the first "$number-" and keep the last (highest)number
    # box_office = box_office.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)
#4. "Million" is sometimes misspelled as "millon."
    #So add a ? after the i of million like this: of milli?on.  Recall the ca?t would qualify ct or cat.
    
form_one = r'\$\s*\d+\.?\d*\s*[mb]illi?on'
form_two = r'\$\s*\d{1,3}(?:[,\.]\d{3})+'

box_office = box_office.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)

# %%
box_office.str.extract(f'({form_one}|{form_two})')
# Out:
#                   0
# 0     $21.4 million
# 1     $2.7 million
# 2     $57,718,089
# 3     $7,331,647
# 4     $6,939,946
# ...          ...
# 7070  $19.4 million
# 7071  $41.9 million
# 7072  $76.1 million
# 7073  $38.4 million
# 7074  $5.5 million
#
# [5485 rows x 1 columns]

# %%
#Turn the extracted values into a numeric values.

def parse_dollars(s):
    # if s is not a string, return NaN
    if type(s) != str:
        return np.nan

    # if input is of the form $###.# million
    if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.IGNORECASE):

        # remove dollar sign and " million"
        s = re.sub('\$|\s|[a-zA-Z]','', s)

        # convert to float and multiply by a million
        value = float(s) * 10**6

        # return value
        return value

    # if input is of the form $###.# billion
    elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):

        # remove dollar sign and " billion"
        s = re.sub('\$|\s|[a-zA-Z]','', s)

        # convert to float and multiply by a billion
        value = float(s) * 10**9

        # return value
        return value

    # if input is of the form $###,###,###
    elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)', s, flags=re.IGNORECASE):

        # remove dollar sign and commas
        s = re.sub('\$|,','', s)

        # convert to float
        value = float(s)

        # return value
        return value

    # otherwise, return NaN
    else:
        return np.nan

# %%
wiki_movies_df['box_office'] = box_office.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)
wiki_movies_df['box_office']
# Out:
# 0       21400000.0
# 1       2700000.0
# 2       57718089.0
# 3       7331647.0
# 4       6939946.0
#           ...
# 7071    41900000.0
# 7072    76100000.0
# 7073    38400000.0
# 7074    5500000.0
# 7075   NaN
# Name: box_office, Length: 7033, dtype: float64
